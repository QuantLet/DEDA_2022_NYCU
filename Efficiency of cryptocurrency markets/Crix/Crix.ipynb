# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

# %%
df_tmp=pd.read_csv(".../CRIXgraphicdata.csv")

# %%
df_tmp
# Out:
#             Date           BTC          ETH         BNB       XRP       ADA  \
# 0     2018-04-01   6844.229980   379.606995   11.066200  0.485081  0.150768
# 1     2018-04-02   7083.799805   386.424988   12.620700  0.500688  0.156385
# 2     2018-04-03   7456.109863   416.893005   13.360700  0.558044  0.172447
# 3     2018-04-04   6853.839844   380.542999   12.190400  0.501631  0.155356
# 4     2018-04-05   6811.470215   383.231995   12.453600  0.495801  0.148758
# ...          ...           ...          ...         ...       ...       ...
# 1670  2022-10-27  20285.835938  1514.374878  286.844116  0.462407  0.388697
# 1671  2022-10-28  20595.351563  1555.477905  298.014191  0.473981  0.404507
# 1672  2022-10-29  20818.476563  1619.698486  304.217957  0.470416  0.419778
# 1673  2022-10-30  20635.603516  1590.783325  313.754791  0.458455  0.406047
# 1674  2022-10-31  20495.773438  1572.714478  326.360718  0.465915  0.406336
#
#            CRIX
# 0      753.4675
# 1      756.7900
# 2      812.9000
# 3      747.3600
# 4      737.8500
# ...         ...
# 1670  1932.6300
# 1671  1934.6900
# 1672  1934.3750
# 1673  1934.2175
# 1674  1934.0600
#
# [1675 rows x 7 columns]

# %%
df_tmp["Date"] = df_tmp["Date"].astype("datetime64")
df_tmp = df_tmp.set_index("Date")

# %%
x = df_tmp.index.values
y = df_tmp.CRIX
fig, ax = plt.subplots()
ax.plot(x,y)
ax.set(xlabel="Date", ylabel="CRIX")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
#plt.savefig('CRIX.png',  bbox_inches='tight')
plt.show()

# %%
import pandas as pd 
import bs4 
import urllib

# %%
# Define URL
# 'Measuring everything except what makes life worthwhile' by Robert F. Kennedy
url = "https://www.neil.blog/full-speech-transcript/measuring-everything-except-what-makes-life-worthwhile-by-robert-f-kennedy"
raw_html = urllib.request.urlopen(url) 
parsed_html = bs4.BeautifulSoup(raw_html, "lxml")
text = parsed_html.find_all("div", class_ = "entry-content") 
# Speech stored in list 
textl = []
for i in text: 
    textl.append(i.get_text())

# %%
text
# Out:
# [<div class="entry-content e-content">
#  <div class="sqs-layout sqs-grid-12 columns-12" data-layout-label="Post Body" data-type="item" data-updated-on="1623706196976" id="item-60c7c78f17bd4c37e4e22dfb"><div class="row sqs-row"><div class="col sqs-col-12 span-12"><div class="sqs-block html-block sqs-block-html" data-block-type="2" id="block-2776272a5fff9ed7e9c4"><div class="sqs-block-content">
#  <p class="" style="white-space:pre-wrap;">Delivered by <a href="https://en.wikipedia.org/wiki/Robert_F._Kennedy">Robert F. Kennedy</a><strong> </strong>at the University of Kansas in 1968<strong> (</strong>Source: <a href="https://www.jfklibrary.org/learn/about-jfk/the-kennedy-family/robert-f-kennedy/robert-f-kennedy-speeches/remarks-at-the-university-of-kansas-march-18-1968">JFK Library</a><strong>) </strong></p>
#  </div></div><div class="sqs-block spacer-block sqs-block-spacer sized vsize-1" data-block-type="21" id="block-8e3c3faaae0ef4fd8f5f"><div class="sqs-block-content"> </div></div><div class="sqs-block html-block sqs-block-html" data-block-type="2" id="block-150367b6c535512b2845"><div class="sqs-block-content">
#  <h2 style="white-space:pre-wrap;"><strong>Context:</strong></h2><h2 style="white-space:pre-wrap;">When I went to business school a couple decades ago a professor handed out the most famous paragraph from this speech by Robert Kennedy. The paragraph shredded GDP and included vivid lines like “It counts Whitman's rifle and Speck's knife, and the television programs which glorify violence in order to sell toys to our children. Yet the gross national product does not allow for the health of our children, the quality of their education or the joy of their play.”</h2><h2 style="white-space:pre-wrap;">I always loved that line, and that larger paragraph, but it was only many years later that I went back to find it and came across the entire speech. It’s a masterpiece. There is so much to learn here about audience connection, shaping a vision, and true servant leadership. You can almost feel the skeptical eyebrows at the beginning and standing ovation at the end. It’s a long speech. Perhaps there's way too much on Vietnam! But Kennedy's ability to transfix an audience while navigating the grey with clarity and confidence is beautiful. If you’re a leader of any stripe, I think it’s worth the time investment in spades.</h2><h2 style="white-space:pre-wrap;">Last thing to note: Bobby Kennedy announced his campaign for Presidency on March 16, 1968, gave this speech at the University of Kansas just two days later, and was assassinated 82 days after that. Consider there was enough 'speech' in this speech to have people threaten and then take his life at age 42. What could have been we'll never know...</h2><h2 style="white-space:pre-wrap;">At a minimum let's reflect on the words together.</h2>
#  </div></div><div class="sqs-block spacer-block sqs-block-spacer sized vsize-1" data-block-type="21" id="block-af9eb1ddf5ba8f32057f"><div class="sqs-block-content"> </div></div><div class="sqs-block html-block sqs-block-html" data-block-type="2" id="block-95f5c16cc83c8c593094"><div class="sqs-block-content">
#  <h2 style="white-space:pre-wrap;"><strong>Speech Transcript:</strong></h2><h2 style="white-space:pre-wrap;">Thank you very much.</h2><h2 style="white-space:pre-wrap;">Chancellor, Governor and Mrs. Docking, Senator and Mrs. Pierson, ladies and gentlemen and my friends, I'm very pleased to be here. I'm really not here to make a speech. I've come because I came from Kansas State and they want to send their love to all of you. They did. That's all they talk about over there, how much they love you. Actually, I want to establish the fact that I am not an alumnus of Villanova.<br/> <br/>I'm very pleased and very touched, as my wife is, at your warm reception here. I think of my colleagues in the United States Senate, I think of my friends there, and I think of the warmth that exists in the Senate of the United States — I don't know why you're laughing — I was sick last year and I received a message from the Senate of the United States which said: "We hope you recover," and the vote was forty-two to forty.<br/> <br/>And then they took a poll in one of the financial magazines of five hundred of the largest businessmen in the United States, to ask them, what political leader they most admired, who they wanted to see as President of the United States, and I received one vote, and I understand they're looking for him. I could take all my supporters to lunch, but I'm — I don't know whether you're going to like what I'm going to say today but I just want you to remember, as you look back upon this day, and when it comes to a question of who you're going to support — that it was a Kennedy who got you out of class.<br/> <br/>I am very pleased to be here with my colleagues, Senator Pierson, who I think has contributed so much in the Senate of the United States — who has fought for the interests of Kansas and has had a distinguished career, and I'm very proud to be associated with him. And Senator Carlson who is not here, who is one of the most respected members of the Senate of the United States — respected not just on the Republican side — by the Democratic side, by all of his colleagues and I'm pleased and proud to be in the Senate with Senator Carlson of the State of Kansas.<br/> <br/>And I'm happy to be here with an old friend, Governor Docking. I don't think there was anyone that was more committed to President Kennedy and made more of an effort under the most adverse circumstances and with the most difficult of situations than his father, who was then Governor of the State of Kansas — nobody I worked with more closely, myself, when I was in Los Angeles. We weren't a hundred percent successful, but that was a relationship that I will always value, and I know how highly President Kennedy valued it and I'm very pleased to see him - and to have seen his mother, Mrs. Docking today also, so I'm very pleased to be in his State.<br/> <br/>And then I'm pleased to be here because I like to see all of you, in addition.<br/> <br/>In 1824, when Thomas Hart Benton was urging in Congress the development of Iowa and other western territories, he was opposed by Daniel Webster, the Senator from Massachusetts. "What," asked Webster, "what do we want with this vast and worthless area? This region of savages and wild beasts. Of deserts of shifting sands and of whirlwinds. Of dust, and of cactus and of prairie dogs.”<br/> <br/>"To what use," he said, "could we ever hope to put these great deserts? I will never vote for one-cent from the public treasury, to place the west one inch closer to Boston, than it is now."</h2><h2 style="white-space:pre-wrap;">And that is why I am here today instead of my brother Edward.<br/> <br/>I'm glad to come here to the home of the man who publicly wrote: "If our colleges and universities do not breed men who riot, who rebel, who attack life with all the youthful vision and vigor, then there is something wrong with our colleges. The more riots that come out of our college campuses, the better the world for tomorrow." And despi ...
#  </div></div><div class="sqs-block spacer-block sqs-block-spacer sized vsize-1" data-aspect-ratio="4.857142857142857" data-block-type="21" id="block-fe7239dc1e2e9f602974"><div class="sqs-block-content"> </div></div><div class="sqs-block html-block sqs-block-html" data-block-type="2" id="block-219120ff3d1adbb64363"><div class="sqs-block-content">
#  <h2 style="white-space:pre-wrap;"><strong>Sign Up for a Dose of Inspiration:</strong></h2><h2 style="white-space:pre-wrap;">Every other week, I send an email out with one of my favorite speeches, essays or poems. No ads, no sponsors, no spam, and nothing for sale. Just a dose of inspiration or beauty!</h2><h2 style="white-space:pre-wrap;"><a href="https://neil.blog/newsletters"><strong>Click here</strong></a> to sign up.</h2>
#  </div></div></div></div></div>
#  </div>]

# %%
textl
# Out:
# ['\n\nDelivered by Robert F. Kennedy at the University of Kansas in 1968 (Source: JFK Library) \n\xa0\nContext:When I went to business school a couple decades ago a professor handed out the most famous paragraph from this speech by Robert Kennedy. The paragraph shredded GDP and included vivid lines like “It counts Whitman\'s rifle and Speck\'s knife, and the television programs which glorify violence in order to sell toys to our children. Yet the gross national product does not allow for the health of our children, the quality of their education or the joy of their play.”I always loved that line, and that larger paragraph, but it was only many years later that I went back to find it and came across the entire speech. It’s a masterpiece. There is so much to learn here about audience connection, shaping a vision, and true servant leadership. You can almost feel the skeptical eyebrows at the beginning and standing ovation at the end. It’s a long speech. Perhaps there\'s way too much on Vietnam! But Kennedy\'s ability to transfix an audience while navigating the grey with clarity and confidence is beautiful. If you’re a leader of any stripe, I think it’s worth the time investment in spades.Last thing to note: Bobby Kennedy announced his campaign for Presidency on March 16, 1968, gave this speech at the University of Kansas just two days later, and was assassinated 82 days after that. Consider there was enough \'speech\' in this speech to have people threaten and then take his life at age 42. What could have been we\'ll never know...At a minimum let\'s reflect on the words together.\n\xa0\nSpeech Transcript:Thank you very much.Chancellor, Governor and Mrs. Docking, Senator and Mrs. Pierson, ladies and gentlemen and my friends, I\'m very pleased to be here. I\'m really not here to make a speech. I\'ve come because I came from Kansas State and they want to send their love to all of you. They did. That\'s all they talk about over there, how much they love you. Actually, I want to establish the fact that I am not an alumnus of Villanova. I\'m very pleased and very touched, as my wife is, at your warm reception here. I think of my colleagues in the United States Senate, I think of my friends there, and I think of the warmth that exists in the Senate of the United States — I don\'t know why you\'re laughing — I was sick last year and I received a message from the Senate of the United States which said: "We hope you recover," and the vote was forty-two to forty. And then they took a poll in one of the financial magazines of five hundred of the largest businessmen in the United States, to ask them, what political leader they most admired, who they wanted to see as President of the United States, and I received one vote, and I understand they\'re looking for him. I could take all my supporters to lunch, but I\'m — I don\'t know whether you\'re going to like what I\'m going to say today but I just want you to remember, as you look back upon this day, and when it comes to a question of who you\'re going to support — that it was a Kennedy who got you out of class. I am very pleased to be here with my colleagues, Senator Pierson, who I think has contributed so much in the Senate of the United States — who has fought for the interests of Kansas and has had a distinguished career, and I\'m very proud to be associated with him. And Senator Carlson who is not here, who is one of the most respected members of the Senate of the United States — respected not just on the Republican side — by the Democratic side, by all of his colleagues and I\'m pleased and proud to be in the Senate with Senator Carlson of the State of Kansas. And I\'m happy to be here with an old friend, Governor Docking. I don\'t think there was anyone that was more committed to President Kennedy and made more of an effort under the most adverse circumstances and with the most difficult of situations than his father, who was then Governor of the State of Kansas — nobody I worked with ...

# %%
# Convert to string 
cleantextprep = str(textl);cleantextprep
# Out:
# '[\'\\n\\nDelivered by Robert F. Kennedy at the University of Kansas in 1968 (Source: JFK Library) \\n\\xa0\\nContext:When I went to business school a couple decades ago a professor handed out the most famous paragraph from this speech by Robert Kennedy. The paragraph shredded GDP and included vivid lines like “It counts Whitman\\\'s rifle and Speck\\\'s knife, and the television programs which glorify violence in order to sell toys to our children. Yet the gross national product does not allow for the health of our children, the quality of their education or the joy of their play.”I always loved that line, and that larger paragraph, but it was only many years later that I went back to find it and came across the entire speech. It’s a masterpiece. There is so much to learn here about audience connection, shaping a vision, and true servant leadership. You can almost feel the skeptical eyebrows at the beginning and standing ovation at the end. It’s a long speech. Perhaps there\\\'s way too much on Vietnam! But Kennedy\\\'s ability to transfix an audience while navigating the grey with clarity and confidence is beautiful. If you’re a leader of any stripe, I think it’s worth the time investment in spades.Last thing to note: Bobby Kennedy announced his campaign for Presidency on March 16, 1968, gave this speech at the University of Kansas just two days later, and was assassinated 82 days after that. Consider there was enough \\\'speech\\\' in this speech to have people threaten and then take his life at age 42. What could have been we\\\'ll never know...At a minimum let\\\'s reflect on the words together.\\n\\xa0\\nSpeech Transcript:Thank you very much.Chancellor, Governor and Mrs. Docking, Senator and Mrs. Pierson, ladies and gentlemen and my friends, I\\\'m very pleased to be here. I\\\'m really not here to make a speech. I\\\'ve come because I came from Kansas State and they want to send their love to all of you. They did. That\\\'s all they talk about over there, how much they love you. Actually, I want to establish the fact that I am not an alumnus of Villanova. I\\\'m very pleased and very touched, as my wife is, at your warm reception here. I think of my colleagues in the United States Senate, I think of my friends there, and I think of the warmth that exists in the Senate of the United States — I don\\\'t know why you\\\'re laughing — I was sick last year and I received a message from the Senate of the United States which said: "We hope you recover," and the vote was forty-two to forty. And then they took a poll in one of the financial magazines of five hundred of the largest businessmen in the United States, to ask them, what political leader they most admired, who they wanted to see as President of the United States, and I received one vote, and I understand they\\\'re looking for him. I could take all my supporters to lunch, but I\\\'m — I don\\\'t know whether you\\\'re going to like what I\\\'m going to say today but I just want you to remember, as you look back upon this day, and when it comes to a question of who you\\\'re going to support — that it was a Kennedy who got you out of class. I am very pleased to be here with my colleagues, Senator Pierson, who I think has contributed so much in the Senate of the United States — who has fought for the interests of Kansas and has had a distinguished career, and I\\\'m very proud to be associated with him. And Senator Carlson who is not here, who is one of the most respected members of the Senate of the United States — respected not just on the Republican side — by the Democratic side, by all of his colleagues and I\\\'m pleased and proud to be in the Senate with Senator Carlson of the State of Kansas. And I\\\'m happy to be here with an old friend, Governor Docking. I don\\\'t think there was anyone that was more committed to President Kennedy and made more of an effort under the most adverse circumstances and with the most difficult of situations than his father, who was ...

# %%
import re
# Clean Speech Text 
expression = "[^a-zA-Z0-9 ]" # keep only letters, numbers and whitespace
cleantextCAP = re.sub(expression, "", cleantextprep) # replace empty string 
cleantext = cleantextCAP.lower()
# Create Dictionary 
dat = list(cleantext.split()) 
cleantext[:100]
# Out:
# 'nndelivered by robert f kennedy at the university of kansas in 1968 source jfk library nxa0ncontextw'

# %%
dat[:10]
# Out:
# ['nndelivered',
#  'by',
#  'robert',
#  'f',
#  'kennedy',
#  'at',
#  'the',
#  'university',
#  'of',
#  'kansas']

# %%
dict1 = {} 
#i=1
for i in range(len(dat)): 
    #print(i) 
    word = dat[i] 
    dict1[word] = dat.count(word) #count the number of "word" in data "dat"

# %%
dict1
# Out:
# {'nndelivered': 1,
#  'by': 14,
#  'robert': 2,
#  'f': 1,
#  'kennedy': 7,
#  'at': 21,
#  'the': 262,
#  'university': 3,
#  'of': 182,
#  'kansas': 8,
#  'in': 90,
#  '1968': 3,
#  'source': 1,
#  'jfk': 1,
#  'library': 1,
#  'nxa0ncontextwhen': 1,
#  'i': 107,
#  'went': 2,
#  'to': 156,
#  'business': 1,
#  'school': 2,
#  'a': 52,
#  'couple': 1,
#  'decades': 1,
#  'ago': 5,
#  'professor': 1,
#  'handed': 1,
#  'out': 10,
#  'most': 6,
#  'famous': 1,
#  'paragraph': 3,
#  'from': 11,
#  'this': 33,
#  'speech': 7,
#  'shredded': 1,
#  'gdp': 1,
#  'and': 178,
#  'included': 1,
#  'vivid': 1,
#  'lines': 1,
#  'like': 6,
#  'it': 36,
#  'counts': 7,
#  'whitmans': 2,
#  'rifle': 2,
#  'specks': 2,
#  'knife': 2,
#  'television': 2,
#  'programs': 2,
#  'which': 6,
#  'glorify': 2,
#  'violence': 2,
#  'order': 4,
#  'sell': 3,
#  'toys': 2,
#  'our': 39,
#  'children': 9,
#  'yet': 2,
#  'gross': 6,
#  'national': 11,
#  'product': 6,
#  'does': 4,
#  'not': 25,
#  'allow': 2,
#  'for': 49,
#  'health': 2,
#  'quality': 2,
#  'their': 28,
#  'education': 2,
#  'or': 13,
#  'joy': 3,
#  'playi': 1,
#  'always': 2,
#  'loved': 1,
#  'that': 104,
#  'line': 1,
#  'larger': 1,
#  'but': 23,
#  'was': 18,
#  'only': 5,
#  'many': 4,
#  'years': 10,
#  'later': 2,
#  'back': 3,
#  'find': 2,
#  'came': 2,
#  'across': 3,
#  'entire': 1,
#  'its': 9,
#  'masterpiece': 1,
#  'there': 15,
#  'is': 43,
#  'so': 25,
#  'much': 9,
#  'learn': 1,
#  'here': 31,
#  'about': 8,
#  'audience': 2,
#  'connection': 1,
#  'shaping': 1,
#  'vision': 2,
#  'true': 3,
#  'servant': 1,
#  'leadership': 3,
#  'you': 15,
#  'can': 28,
#  'almost': 1,
#  'feel': 4,
#  'skeptical': 1,
#  'eyebrows': 1,
#  'beginning': 2,
#  'standing': 1,
#  'ovation': 1,
#  'end': 3,
#  'long': 2,
#  'perhaps': 1,
#  'theres': 3,
#  'way': 3,
#  'too': 4,
#  'on': 13,
#  'vietnam': 23,
#  'kennedys': 1,
#  'ability': 1,
#  'transfix': 1,
#  'an': 10,
#  'while': 2,
#  'navigating': 1,
#  'grey': 1,
#  'with': 32,
#  'clarity': 1,
#  'confidence': 3,
#  'beautiful': 1,
#  'if': 17,
#  'youre': 4,
#  'leader': 2,
#  'any': 2,
#  'stripe': 1,
#  'think': 46,
#  'worth': 3,
#  'time': 4,
#  'investment': 1,
#  'spadeslast': 1,
#  'thing': 1,
#  'note': 1,
#  'bobby': 1,
#  'announced': 1,
#  'his': 8,
#  'campaign': 1,
#  'presidency': 4,
#  'march': 1,
#  '16': 1,
#  'gave': 1,
#  'just': 13,
#  'two': 4,
#  'days': 3,
#  'assassinated': 1,
#  '82': 1,
#  'after': 3,
#  'consider': 1,
#  'enough': 6,
#  'have': 49,
#  'people': 20,
#  'threaten': 2,
#  'then': 6,
#  'take': 4,
#  'life': 5,
#  'age': 3,
#  '42': 1,
#  'what': 13,
#  'could': 4,
#  'been': 5,
#  'well': 2,
#  'never': 3,
#  'knowat': 1,
#  'minimum': 1,
#  'lets': 1,
#  'reflect': 1,
#  'words': 3,
#  'togethernxa0nspeech': 1,
#  'transcriptthank': 1,
#  'very': 10,
#  'muchchancellor': 1,
#  'governor': 3,
#  'mrs': 3,
#  'docking': 3,
#  'senator': 5,
#  'pierson': 2,
#  'ladies': 1,
#  'gentlemen': 1,
#  'my': 9,
#  'friends': 2,
#  'im': 13,
#  'pleased': 7,
#  'be': 18,
#  'really': 1,
#  'make': 9,
#  'ive': 2,
#  'come': 4,
#  'because': 5,
#  'state': 4,
#  'they': 22,
#  'want': 21,
#  'send': 5,
#  'love': 3,
#  'all': 16,
#  'did': 3,
#  'thats': 10,
#  'talk': 1,
#  'over': 6,
#  'how': 2,
#  'actually': 1,
#  'establish': 1,
#  'fact': 4,
#  'am': 7,
#  'alumnus': 1,
#  'villanova': 1,
#  'touched': 1,
#  'as': 27,
#  'wife': 1,
#  'your': 9,
#  'warm': 1,
#  'reception': 1,
#  'colleagues': 3,
#  'united': 43,
#  'states': 43,
#  'senate': 6,
#  'warmth': 1,
#  'exists': 2,
#  'dont': 25,
#  'know': 5,
#  'why': 10,
#  'laughing': 1,
#  'sick': 1,
#  'last': 6,
#  'year': 8,
#  'received': 2,
#  'message': 2,
#  'said': 6,
#  'we': 86,
#  'hope': 5,
#  'recover': 1,
#  'vote': 3,
#  'fortytwo': 1,
#  'forty': 1,
#  'took': 1,
#  'poll': 1,
#  'one': 14,
#  'financial': 1,
#  'magazines': 1,
#  'five': 3,
#  'hundred': 2,
#  'largest': 1,
#  'businessmen': 1,
#  'ask': 4,
#  'them': 14,
#  'political': 4,
#  'admired': 1,
#  'who': 16,
#  'wanted': 1,
#  'see': 7,
#  'president': 12,
#  'understand': 2,
#  'theyre': 3,
#  'looking': 2,
#  'him': 4,
#  'supporters': 1,
#  'lunch': 1,
#  'whether': 3,
#  'going': 26,
#  'say': 5,
#  'today': 5,
#  'remember': 1,
#  'look': 4,
#  'upon': 3,
#  'day': 1,
#  'when': 9,
#  'comes': 1,
#  'question': 6,
#  'support': 4,
#  'got': 1,
#  'class': 1,
#  'has': 10,
#  'contributed': 1,
#  'fought': 1,
#  'interests': 1,
#  'had': 6,
#  'distinguished': 1,
#  'career': 1,
#  'proud': 4,
#  'associated': 1,
#  'carlson': 2,
#  'respected': 2,
#  'members': 1,
#  'republican': 1,
#  'side': 2,
#  'democratic': 1,
#  'happy': 1,
#  'old': 4,
#  'friend': 1,
#  'anyone': 1,
#  'more': 12,
#  'committed': 1,
#  'made': 5,
#  'effort': 4,
#  'under': 1,
#  'adverse': 1,
#  'circumstances': 1,
#  'difficult': 2,
#  'situations': 1,
#  'than': 8,
#  'father': 1,
#  'nobody': 1,
#  'worked': 1,
#  'closely': 1,
#  'myself': 1,
#  'los': 1,
#  'angeles': 1,
#  'werent': 1,
#  'percent': 2,
#  'successful': 1,
#  'relationship': 1,
#  'will': 8,
#  'value': 1,
#  'highly': 1,
#  'valued': 1,
#  'seen': 8,
#  'mother': 1,
#  'also': 3,
#  'addition': 1,
#  '1824': 1,
#  'thomas': 1,
#  'hart': 1,
#  'benton': 1,
#  'urging': 1,
#  'congress': 1,
#  'development': 2,
#  'iowa': 1,
#  'other': 13,
#  'western': 1,
#  'territories': 1,
#  'he': 15,
#  'opposed': 1,
#  'daniel': 1,
#  'webster': 2,
#  'massachusetts': 1,
#  'asked': 1,
#  'do': 17,
#  'vast': 1,
#  'worthless': 1,
#  'area': 3,
#  'region': 1,
#  'savages': 1,
#  'wild': 1,
#  'beasts': 1,
#  'deserts': 2,
#  'shifting': 1,
#  'sands': 1,
#  'whirlwinds': 1,
#  'dust': 1,
#  'cactus': 1,
#  'prairie': 1,
#  'dogs': 1,
#  'use': 1,
#  'ever': 2,
#  'put': 2,
#  'these': 4,
#  'great': 3,
#  'onecent': 1,
#  'public': 4,
#  'treasury': 1,
#  'place': 1,
#  'west': 1,
#  'inch': 1,
#  'closer': 1,
#  'boston': 1,
#  'nowand': 1,
#  'instead': 1,
#  'brother': 1,
#  'edward': 1,
#  'glad': 1,
#  'home': 2,
#  'man': 2,
#  'publicly': 1,
#  'wrote': 4,
#  'colleges': 2,
#  'universities': 1,
#  'breed': 1,
#  'men': 9,
#  'riot': 1,
#  'rebel': 1,
#  'attack': 1,
#  'youthful': 1,
#  'vigor': 1,
#  'something': 2,
#  'wrong': 2,
#  'riots': 2,
#  'college': 1,
#  'campuses': 1,
#  'better': 10,
#  'world': 2,
#  'tomorrow': 1,
#  'despite': 1,
#  'accusations': 1,
#  'against': 1,
#  'me': 2,
#  'those': 3,
#  'were': 15,
#  'written': 2,
#  'notorious': 1,
#  'seditionist': 1,
#  'william': 1,
#  'allen': 1,
#  'white': 3,
#  'affection': 1,
#  'honored': 1,
#  'campus': 1,
#  'around': 8,
#  'rest': 3,
#  'nation': 2,
#  'lived': 1,
#  'reviled': 1,
#  'extremist': 1,
#  'worse': 1,
#  'spoke': 3,
#  'believed': 1,
#  'conceal': 1,
#  'concern': 2,
#  'comforting': 1,
#  'delude': 1,
#  'readers': 1,
#  'himself': 1,
#  'false': 2,
#  'hopes': 2,
#  'illusions': 2,
#  'spirit': 3,
#  'honest': 1,
#  'confrontation': 1,
#  'america': 16,
#  'needs': 2,
#  'missing': 1,
#  'often': 1,
#  'recent': 1,
#  'reasons': 1,
#  'run': 5,
#  'are': 29,
#  'strong': 1,
#  'brave': 1,
#  'told': 1,
#  'truth': 2,
#  'where': 3,
#  'stand': 2,
#  'country': 10,
#  'honesty': 1,
#  'candor': 1,
#  'critical': 2,
#  'choice': 1,
#  'direction': 2,
#  'without': 2,
#  'confronting': 1,
#  'win': 4,
#  'votes': 1,
#  'hiding': 1,
#  'american': 15,
#  'condition': 2,
#  'us': 20,
#  'promise': 2,
#  'future': 7,
#  'accomplish': 1,
#  'expected': 1,
#  'ahead': 2,
#  'examine': 1,
#  'weve': 1,
#  'gone': 2,
#  'young': 7,
#  'chance': 2,
#  'build': 1,
#  'change': 4,
#  'morning': 1,
#  'war': 10,
#  'speak': 1,
#  'briefly': 1,
#  'few': 2,
#  'moments': 1,
#  'election': 1,
#  'root': 2,
#  'soul': 1,
#  'calls': 1,
#  'restlessness': 1,
#  'cabinet': 1,
#  'officers': 1,
#  'such': 2,
#  'john': 1,
#  'gardiner': 1,
#  'others': 1,
#  'tell': 2,
#  'deep': 3,
#  'malaise': 1,
#  'discouraging': 1,
#  'initiative': 1,
#  'paralyzing': 1,
#  'action': 6,
#  'dividing': 1,
#  'americans': 7,
#  'another': 3,
#  'views': 1,
#  'color': 1,
#  'skin': 1,
#  'accept': 8,
#  'demonstrators': 2,
#  'shout': 1,
#  'down': 2,
#  'government': 15,
#  'officials': 2,
#  'answers': 2,
#  'drafting': 1,
#  'anarchists': 1,
#  'burn': 1,
#  'some': 3,
#  'begun': 1,
#  'try': 1,
#  'tanks': 1,
#  'patrolled': 1,
#  'streets': 1,
#  'machine': 1,
#  'guns': 1,
#  'fired': 1,
#  'satisfying': 1,
#  'situation': 2,
#  'best': 3,
#  'educated': 1,
#  'comforted': 1,
#  'history': 1,
#  'turn': 1,
#  'peace': 2,
#  'corps': 1,
#  'commitment': 2,
#  'lives': 4,
#  'disengagement': 1,
#  'despair': 3,
#  'turned': 2,
#  'drugs': 1,
#  'off': 3,
#  'none': 1,
#  'course': 5,
#  'right': 2,
#  'cities': 4,
#  'poverty': 3,
#  'problems': 1,
#  'race': 1,
#  'relations': 1,
#  'concerned': 4,
#  'disturbed': 1,
#  'lost': 1,
#  'themselves': 5,
#  'each': 6,
#  'sustained': 1,
#  'past': 1,
#  'rather': 2,
#  'answer': 2,
#  'cries': 3,
#  'deprivation': 1,
#  'presidents': 1,
#  'commission': 1,
#  'civil': 1,
#  'disorders': 1,
#  'tells': 1,
#  'split': 1,
#  'finally': 1,
#  'asunder': 1,
#  'desperate': 1,
#  'hundreds': 1,
#  'communities': 1,
#  'millions': 4,
#  'citizens': 2,
#  'force': 1,
#  'repression': 1,
#  'private': 1,
#  'gun': 1,
#  'stocks': 1,
#  'confront': 3,
#  'fellow': 1,
#  'citizen': 1,
#  'impossible': 1,
#  'barriers': 1,
#  'hostility': 1,
#  'mistrust': 1,
#  'again': 1,
#  'believe': 7,
#  'necessary': 1,
#  'work': 2,
#  'together': 2,
#  'shoot': 2,
#  'beat': 1,
#  'curse': 1,
#  'criticize': 1,
#  'countryand': 1,
#  'seem': 1,
#  'powerless': 1,
#  'stop': 1,
#  'growing': 1,
#  'division': 1,
#  'between': 1,
#  'least': 1,
#  'living': 2,
#  'hidden': 1,
#  'places': 1,
#  'whose': 2,
#  'names': 1,
#  'faces': 2,
#  'completely': 1,
#  'unknown': 1,
#  'mississippi': 3,
#  'starving': 1,
#  'bodies': 1,
#  'crippled': 1,
#  'hunger': 1,
#  'minds': 1,
#  'destroyed': 1,
#  'whole': 2,
#  'no': 10,
#  '800': 2,
#  'billion': 2,
#  'dollars': 2,
#  'delta': 1,
#  'distended': 1,
#  'stomachs': 1,
#  'covered': 1,
#  'sores': 1,
#  'starvation': 1,
#  'havent': 1,
#  'developed': 1,
#  'policy': 2,
#  'get': 1,
#  'food': 1,
#  'live': 1,
#  'destroyedi': 1,
#  'acceptable': 3,
#  'need': 2,
#  'indians': 1,
#  'bare': 1,
#  'meager': 1,
#  'reservations': 1,
#  'jobs': 2,
#  'unemployment': 1,
#  'rate': 1,
#  'eighty': 1,
#  'little': 2,
#  'women': 1,
#  'teens': 1,
#  'greatest': 2,
#  'cause': 1,
#  'death': 1,
#  'amongst': 1,
#  'suicide': 1,
#  'killing': 1,
#  'first': 1,
#  'minority': 1,
#  'boys': 2,
#  'girls': 1,
#  'filled': 1,
#  'high': 1,
#  'hopeless': 1,
#  'nobodys': 3,
#  'care': 1,
#  'involved': 1,
#  'bother': 1,
#  'either': 2,
#  'hang': 1,
#  'kill': 1,
#  'americai': 1,
#  'betterand': 1,
#  'hills': 1,
#  'appalachia': 1,
#  'wish': 2,
#  'dignity': 2,
#  'cannot': 1,
#  'mines': 1,
#  'closed': 1,
#  'neither': 4,
#  'industry': 1,
#  'nor': 5,
#  'labor': 1,
#  'cared': 1,
#  'help': 8,
#  'unselfish': 1,
#  'black': 1,
#  'ghetto': 1,
#  'listening': 1,
#  'greater': 2,
#  'promises': 1,
#  'equality': 1,
#  'justice': 1,
#  'sit': 1,
#  'same': 2,
#  'decaying': 1,
#  'schools': 1,
#  'huddled': 1,
#  'filthy': 1,
#  'rooms': 1,
#  'heat': 1,
#  'warding': 2,
#  'cold': 1,
#  'rats': 1,
#  'bound': 1,
#  'common': 1,
#  'urgent': 1,
#  'priority': 1,
#  'must': 2,
#  'begin': 2,
#  'disgrace': 1,
#  'tasks': 1,
#  'individuals': 1,
#  'even': 1,
#  'act': 1,
#  'erase': 1,
#  'material': 2,
#  'task': 1,
#  'satisfaction': 1,
#  'purpose': 1,
#  'afflicts': 1,
#  'seemed': 1,
#  'surrendered': 1,
#  'personal': 1,
#  'excellence': 1,
#  'community': 1,
#  'values': 1,
#  'mere': 1,
#  'accumulation': 1,
#  'things': 5,
#  'now': 3,
#  'judge': 1,
#  'air': 1,
#  'pollution': 1,
#  'cigarette': 1,
#  'advertising': 1,
#  'ambulances': 1,
#  'clear': 4,
#  'highways': 1,
#  'carnage': 1,
#  'special': 1,
#  'locks': 1,
#  'doors': 1,
#  'jails': 1,
#  'break': 1,
#  'destruction': 1,
#  'redwood': 1,
#  'loss': 2,
#  'natural': 1,
#  'wonder': 2,
#  'chaotic': 1,
#  'sprawl': 1,
#  'napalm': 1,
#  'nuclear': 1,
#  'warheads': 1,
#  'armored': 1,
#  'cars': 1,
#  'police': 1,
#  'fight': 3,
#  'play': 3,
#  'include': 1,
#  'beauty': 1,
#  'poetry': 1,
#  'strength': 1,
#  'marriages': 1,
#  'intelligence': 1,
#  'debate': 1,
#  'integrity': 1,
#  'measures': 2,
#  'wit': 1,
#  'courage': 1,
#  'wisdom': 1,
#  'learning': 1,
#  'compassion': 1,
#  'devotion': 1,
#  'everything': 3,
#  'short': 1,
#  'except': 2,
#  'makes': 1,
#  'worthwhile': 1,
#  'elsewhere': 2,
#  'proudest': 1,
#  'boast': 1,
#  'jefferson': 1,
#  'would': 4,
#  'mankind': 2,
#  'still': 1,
#  'hold': 1,
#  'decent': 1,
#  'respect': 3,
#  'opinions': 1,
#  'opinion': 1,
#  'maintained': 1,
#  'descent': 1,
#  'athens': 1,
#  'forfeit': 1,
#  'sympathy': 1,
#  'ultimately': 2,
#  'security': 1,
#  'singleminded': 1,
#  'pursuit': 1,
#  'own': 3,
#  'goals': 1,
#  'objectivesi': 1,
#  'americas': 2,
#  'interest': 1,
#  'simply': 1,
#  'withdraw': 1,
#  'raise': 2,
#  'flag': 2,
#  'surrender': 4,
#  'unacceptable': 5,
#  'presently': 1,
#  'following': 1,
#  'south': 20,
#  'number': 1,
#  'vietnamese': 5,
#  'cant': 1,
#  'period': 6,
#  'three': 4,
#  'struggle': 2,
#  'idea': 1,
#  'military': 7,
#  'every': 2,
#  'difficulties': 1,
#  'southeast': 2,
#  'asia': 2,
#  'response': 1,
#  'deal': 1,
#  'month': 2,
#  'dealt': 1,
#  'increase': 1,
#  'power': 1,
#  'kind': 1,
#  'feeling': 1,
#  'efforts': 1,
#  'sacrifice': 1,
#  'fighting': 2,
#  'several': 1,
#  'shown': 1,
#  'demonstrated': 1,
#  'association': 1,
#  'affiliation': 1,
#  'saigon': 5,
#  'up': 3,
#  'destroy': 2,
#  'commander': 1,
#  'forces': 2,
#  'ben': 1,
#  'tre': 1,
#  'city': 2,
#  'save': 1,
#  'thirtyeight': 1,
#  'thousand': 1,
#  'wiped': 1,
#  'refugees': 1,
#  'commanders': 1,
#  'human': 1,
#  'being': 1,
#  'room': 1,
#  'part': 4,
#  'decision': 1,
#  'longer': 1,
#  'should': 9,
#  'write': 1,
#  'rome': 1,
#  'desert': 1,
#  'called': 1,
#  'go': 5,
#  'negotiating': 4,
#  'table': 4,
#  'steps': 1,
#  'negotiations': 3,
#  'possibility': 1,
#  'meaningful': 1,
#  'february': 3,
#  'opportunity': 1,
#  'existed': 1,
#  'administration': 1,
#  'felt': 1,
#  'victory': 2,
#  'corner': 1,
#  'sent': 1,
#  'ho': 1,
#  'chi': 1,
#  'minh': 1,
#  '8th': 1,
#  '1967': 1,
#  'virtually': 1,
#  'asking': 1,
#  'unconditional': 3,
#  'obtain': 2,
#  'north': 2,
#  'viet': 1,
#  'cong': 1,
#  'anymore': 1,
#  'negotiate': 4,
#  'compromises': 1,
#  'liberation': 3,
#  'front': 3,
#  'argue': 1,
#  'unfortunate': 1,
#  'lifewe': 1,
#  'choiceswe': 1,
#  'pull': 1,
#  'unilaterally': 1,
#  'second': 1,
#  'continue': 3,
#  'escalate': 1,
#  'until': 1,
#  'bomb': 1,
#  'judgment': 1,
#  'nearer': 2,
#  'success': 1,
#  'third': 1,
#  'step': 1,
#  'achieve': 1,
#  'alternative': 1,
#  'role': 2,
#  'process': 2,
#  'elections': 1,
#  'determine': 1,
#  'decide': 1,
#  'tolerate': 1,
#  'corruption': 1,
#  'dishonesty': 1,
#  'draft': 3,
#  'eighteen': 1,
#  'nineteen': 1,
#  'die': 1,
#  'khe': 3,
#  'sanh': 2,
#  'eighteenyearolds': 1,
#  'nineteenyearolds': 1,
#  'feels': 1,
#  'que': 1,
#  'son': 1,
#  'demilitarized': 1,
#  'zone': 1,
#  'important': 2,
#  'san': 1,
#  'marines': 1,
#  'troops': 1,
#  'explanation': 1,
#  'killed': 1,
#  'weeks': 2,
#  'times': 2,
#  'soldiers': 1,
#  'casualties': 2,
#  'deaths': 1,
#  'height': 1,
#  'heavily': 1,
#  'compared': 1,
#  'carry': 1,
#  'burden': 1,
#  'elected': 1,
#  'kinds': 1,
#  'policies': 2,
#  'into': 2,
#  'operation': 1,
#  'relationships': 1,
#  'countries': 1,
#  'globe': 3,
#  'campaigned': 1,
#  '1960': 1,
#  'talked': 1,
#  'prestige': 1,
#  'suffered': 1,
#  'present': 1,
#  'goes': 1,
#  'meeting': 1,
#  'oas': 1,
#  'montevideo': 3,
#  'travel': 2,
#  'through': 1,
#  'latin': 1,
#  'stay': 1,
#  'base': 1,
#  'ships': 1,
#  'sea': 1,
#  'helicopters': 1,
#  'overhead': 1,
#  'ensure': 1,
#  'hes': 1,
#  'protected': 1,
#  'conditions': 1,
#  'freely': 1,
#  'clearly': 1,
#  'bases': 1,
#  'internally': 2,
#  'moment': 1,
#  'george': 1,
#  'bernard': 1,
#  'shaw': 1,
#  'once': 1,
#  'dream': 1,
#  'months': 2,
#  'before': 1,
#  'convention': 1,
#  'chicago': 1,
#  'assistance': 2,
#  ...}

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Unsorted speech constituents in dictionary as dict1 
keys = list(dict1) 
filtered_words = [word for word in keys if word not in stopwords.words('english')] 
dict2 = dict((k, dict1[k]) for k in filtered_words if k in filtered_words)

print(len(dict2))
dict2
# Out:
# 921
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/youcefnazimtahari/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'nndelivered': 1,
#  'robert': 2,
#  'f': 1,
#  'kennedy': 7,
#  'university': 3,
#  'kansas': 8,
#  '1968': 3,
#  'source': 1,
#  'jfk': 1,
#  'library': 1,
#  'nxa0ncontextwhen': 1,
#  'went': 2,
#  'business': 1,
#  'school': 2,
#  'couple': 1,
#  'decades': 1,
#  'ago': 5,
#  'professor': 1,
#  'handed': 1,
#  'famous': 1,
#  'paragraph': 3,
#  'speech': 7,
#  'shredded': 1,
#  'gdp': 1,
#  'included': 1,
#  'vivid': 1,
#  'lines': 1,
#  'like': 6,
#  'counts': 7,
#  'whitmans': 2,
#  'rifle': 2,
#  'specks': 2,
#  'knife': 2,
#  'television': 2,
#  'programs': 2,
#  'glorify': 2,
#  'violence': 2,
#  'order': 4,
#  'sell': 3,
#  'toys': 2,
#  'children': 9,
#  'yet': 2,
#  'gross': 6,
#  'national': 11,
#  'product': 6,
#  'allow': 2,
#  'health': 2,
#  'quality': 2,
#  'education': 2,
#  'joy': 3,
#  'playi': 1,
#  'always': 2,
#  'loved': 1,
#  'line': 1,
#  'larger': 1,
#  'many': 4,
#  'years': 10,
#  'later': 2,
#  'back': 3,
#  'find': 2,
#  'came': 2,
#  'across': 3,
#  'entire': 1,
#  'masterpiece': 1,
#  'much': 9,
#  'learn': 1,
#  'audience': 2,
#  'connection': 1,
#  'shaping': 1,
#  'vision': 2,
#  'true': 3,
#  'servant': 1,
#  'leadership': 3,
#  'almost': 1,
#  'feel': 4,
#  'skeptical': 1,
#  'eyebrows': 1,
#  'beginning': 2,
#  'standing': 1,
#  'ovation': 1,
#  'end': 3,
#  'long': 2,
#  'perhaps': 1,
#  'theres': 3,
#  'way': 3,
#  'vietnam': 23,
#  'kennedys': 1,
#  'ability': 1,
#  'transfix': 1,
#  'navigating': 1,
#  'grey': 1,
#  'clarity': 1,
#  'confidence': 3,
#  'beautiful': 1,
#  'youre': 4,
#  'leader': 2,
#  'stripe': 1,
#  'think': 46,
#  'worth': 3,
#  'time': 4,
#  'investment': 1,
#  'spadeslast': 1,
#  'thing': 1,
#  'note': 1,
#  'bobby': 1,
#  'announced': 1,
#  'campaign': 1,
#  'presidency': 4,
#  'march': 1,
#  '16': 1,
#  'gave': 1,
#  'two': 4,
#  'days': 3,
#  'assassinated': 1,
#  '82': 1,
#  'consider': 1,
#  'enough': 6,
#  'people': 20,
#  'threaten': 2,
#  'take': 4,
#  'life': 5,
#  'age': 3,
#  '42': 1,
#  'could': 4,
#  'well': 2,
#  'never': 3,
#  'knowat': 1,
#  'minimum': 1,
#  'lets': 1,
#  'reflect': 1,
#  'words': 3,
#  'togethernxa0nspeech': 1,
#  'transcriptthank': 1,
#  'muchchancellor': 1,
#  'governor': 3,
#  'mrs': 3,
#  'docking': 3,
#  'senator': 5,
#  'pierson': 2,
#  'ladies': 1,
#  'gentlemen': 1,
#  'friends': 2,
#  'im': 13,
#  'pleased': 7,
#  'really': 1,
#  'make': 9,
#  'ive': 2,
#  'come': 4,
#  'state': 4,
#  'want': 21,
#  'send': 5,
#  'love': 3,
#  'thats': 10,
#  'talk': 1,
#  'actually': 1,
#  'establish': 1,
#  'fact': 4,
#  'alumnus': 1,
#  'villanova': 1,
#  'touched': 1,
#  'wife': 1,
#  'warm': 1,
#  'reception': 1,
#  'colleagues': 3,
#  'united': 43,
#  'states': 43,
#  'senate': 6,
#  'warmth': 1,
#  'exists': 2,
#  'dont': 25,
#  'know': 5,
#  'laughing': 1,
#  'sick': 1,
#  'last': 6,
#  'year': 8,
#  'received': 2,
#  'message': 2,
#  'said': 6,
#  'hope': 5,
#  'recover': 1,
#  'vote': 3,
#  'fortytwo': 1,
#  'forty': 1,
#  'took': 1,
#  'poll': 1,
#  'one': 14,
#  'financial': 1,
#  'magazines': 1,
#  'five': 3,
#  'hundred': 2,
#  'largest': 1,
#  'businessmen': 1,
#  'ask': 4,
#  'political': 4,
#  'admired': 1,
#  'wanted': 1,
#  'see': 7,
#  'president': 12,
#  'understand': 2,
#  'theyre': 3,
#  'looking': 2,
#  'supporters': 1,
#  'lunch': 1,
#  'whether': 3,
#  'going': 26,
#  'say': 5,
#  'today': 5,
#  'remember': 1,
#  'look': 4,
#  'upon': 3,
#  'day': 1,
#  'comes': 1,
#  'question': 6,
#  'support': 4,
#  'got': 1,
#  'class': 1,
#  'contributed': 1,
#  'fought': 1,
#  'interests': 1,
#  'distinguished': 1,
#  'career': 1,
#  'proud': 4,
#  'associated': 1,
#  'carlson': 2,
#  'respected': 2,
#  'members': 1,
#  'republican': 1,
#  'side': 2,
#  'democratic': 1,
#  'happy': 1,
#  'old': 4,
#  'friend': 1,
#  'anyone': 1,
#  'committed': 1,
#  'made': 5,
#  'effort': 4,
#  'adverse': 1,
#  'circumstances': 1,
#  'difficult': 2,
#  'situations': 1,
#  'father': 1,
#  'nobody': 1,
#  'worked': 1,
#  'closely': 1,
#  'los': 1,
#  'angeles': 1,
#  'werent': 1,
#  'percent': 2,
#  'successful': 1,
#  'relationship': 1,
#  'value': 1,
#  'highly': 1,
#  'valued': 1,
#  'seen': 8,
#  'mother': 1,
#  'also': 3,
#  'addition': 1,
#  '1824': 1,
#  'thomas': 1,
#  'hart': 1,
#  'benton': 1,
#  'urging': 1,
#  'congress': 1,
#  'development': 2,
#  'iowa': 1,
#  'western': 1,
#  'territories': 1,
#  'opposed': 1,
#  'daniel': 1,
#  'webster': 2,
#  'massachusetts': 1,
#  'asked': 1,
#  'vast': 1,
#  'worthless': 1,
#  'area': 3,
#  'region': 1,
#  'savages': 1,
#  'wild': 1,
#  'beasts': 1,
#  'deserts': 2,
#  'shifting': 1,
#  'sands': 1,
#  'whirlwinds': 1,
#  'dust': 1,
#  'cactus': 1,
#  'prairie': 1,
#  'dogs': 1,
#  'use': 1,
#  'ever': 2,
#  'put': 2,
#  'great': 3,
#  'onecent': 1,
#  'public': 4,
#  'treasury': 1,
#  'place': 1,
#  'west': 1,
#  'inch': 1,
#  'closer': 1,
#  'boston': 1,
#  'nowand': 1,
#  'instead': 1,
#  'brother': 1,
#  'edward': 1,
#  'glad': 1,
#  'home': 2,
#  'man': 2,
#  'publicly': 1,
#  'wrote': 4,
#  'colleges': 2,
#  'universities': 1,
#  'breed': 1,
#  'men': 9,
#  'riot': 1,
#  'rebel': 1,
#  'attack': 1,
#  'youthful': 1,
#  'vigor': 1,
#  'something': 2,
#  'wrong': 2,
#  'riots': 2,
#  'college': 1,
#  'campuses': 1,
#  'better': 10,
#  'world': 2,
#  'tomorrow': 1,
#  'despite': 1,
#  'accusations': 1,
#  'written': 2,
#  'notorious': 1,
#  'seditionist': 1,
#  'william': 1,
#  'allen': 1,
#  'white': 3,
#  'affection': 1,
#  'honored': 1,
#  'campus': 1,
#  'around': 8,
#  'rest': 3,
#  'nation': 2,
#  'lived': 1,
#  'reviled': 1,
#  'extremist': 1,
#  'worse': 1,
#  'spoke': 3,
#  'believed': 1,
#  'conceal': 1,
#  'concern': 2,
#  'comforting': 1,
#  'delude': 1,
#  'readers': 1,
#  'false': 2,
#  'hopes': 2,
#  'illusions': 2,
#  'spirit': 3,
#  'honest': 1,
#  'confrontation': 1,
#  'america': 16,
#  'needs': 2,
#  'missing': 1,
#  'often': 1,
#  'recent': 1,
#  'reasons': 1,
#  'run': 5,
#  'strong': 1,
#  'brave': 1,
#  'told': 1,
#  'truth': 2,
#  'stand': 2,
#  'country': 10,
#  'honesty': 1,
#  'candor': 1,
#  'critical': 2,
#  'choice': 1,
#  'direction': 2,
#  'without': 2,
#  'confronting': 1,
#  'win': 4,
#  'votes': 1,
#  'hiding': 1,
#  'american': 15,
#  'condition': 2,
#  'us': 20,
#  'promise': 2,
#  'future': 7,
#  'accomplish': 1,
#  'expected': 1,
#  'ahead': 2,
#  'examine': 1,
#  'weve': 1,
#  'gone': 2,
#  'young': 7,
#  'chance': 2,
#  'build': 1,
#  'change': 4,
#  'morning': 1,
#  'war': 10,
#  'speak': 1,
#  'briefly': 1,
#  'moments': 1,
#  'election': 1,
#  'root': 2,
#  'soul': 1,
#  'calls': 1,
#  'restlessness': 1,
#  'cabinet': 1,
#  'officers': 1,
#  'john': 1,
#  'gardiner': 1,
#  'others': 1,
#  'tell': 2,
#  'deep': 3,
#  'malaise': 1,
#  'discouraging': 1,
#  'initiative': 1,
#  'paralyzing': 1,
#  'action': 6,
#  'dividing': 1,
#  'americans': 7,
#  'another': 3,
#  'views': 1,
#  'color': 1,
#  'skin': 1,
#  'accept': 8,
#  'demonstrators': 2,
#  'shout': 1,
#  'government': 15,
#  'officials': 2,
#  'answers': 2,
#  'drafting': 1,
#  'anarchists': 1,
#  'burn': 1,
#  'begun': 1,
#  'try': 1,
#  'tanks': 1,
#  'patrolled': 1,
#  'streets': 1,
#  'machine': 1,
#  'guns': 1,
#  'fired': 1,
#  'satisfying': 1,
#  'situation': 2,
#  'best': 3,
#  'educated': 1,
#  'comforted': 1,
#  'history': 1,
#  'turn': 1,
#  'peace': 2,
#  'corps': 1,
#  'commitment': 2,
#  'lives': 4,
#  'disengagement': 1,
#  'despair': 3,
#  'turned': 2,
#  'drugs': 1,
#  'none': 1,
#  'course': 5,
#  'right': 2,
#  'cities': 4,
#  'poverty': 3,
#  'problems': 1,
#  'race': 1,
#  'relations': 1,
#  'concerned': 4,
#  'disturbed': 1,
#  'lost': 1,
#  'sustained': 1,
#  'past': 1,
#  'rather': 2,
#  'answer': 2,
#  'cries': 3,
#  'deprivation': 1,
#  'presidents': 1,
#  'commission': 1,
#  'civil': 1,
#  'disorders': 1,
#  'tells': 1,
#  'split': 1,
#  'finally': 1,
#  'asunder': 1,
#  'desperate': 1,
#  'hundreds': 1,
#  'communities': 1,
#  'millions': 4,
#  'citizens': 2,
#  'force': 1,
#  'repression': 1,
#  'private': 1,
#  'gun': 1,
#  'stocks': 1,
#  'confront': 3,
#  'fellow': 1,
#  'citizen': 1,
#  'impossible': 1,
#  'barriers': 1,
#  'hostility': 1,
#  'mistrust': 1,
#  'believe': 7,
#  'necessary': 1,
#  'work': 2,
#  'together': 2,
#  'shoot': 2,
#  'beat': 1,
#  'curse': 1,
#  'criticize': 1,
#  'countryand': 1,
#  'seem': 1,
#  'powerless': 1,
#  'stop': 1,
#  'growing': 1,
#  'division': 1,
#  'least': 1,
#  'living': 2,
#  'hidden': 1,
#  'places': 1,
#  'whose': 2,
#  'names': 1,
#  'faces': 2,
#  'completely': 1,
#  'unknown': 1,
#  'mississippi': 3,
#  'starving': 1,
#  'bodies': 1,
#  'crippled': 1,
#  'hunger': 1,
#  'minds': 1,
#  'destroyed': 1,
#  'whole': 2,
#  '800': 2,
#  'billion': 2,
#  'dollars': 2,
#  'delta': 1,
#  'distended': 1,
#  'stomachs': 1,
#  'covered': 1,
#  'sores': 1,
#  'starvation': 1,
#  'havent': 1,
#  'developed': 1,
#  'policy': 2,
#  'get': 1,
#  'food': 1,
#  'live': 1,
#  'destroyedi': 1,
#  'acceptable': 3,
#  'need': 2,
#  'indians': 1,
#  'bare': 1,
#  'meager': 1,
#  'reservations': 1,
#  'jobs': 2,
#  'unemployment': 1,
#  'rate': 1,
#  'eighty': 1,
#  'little': 2,
#  'women': 1,
#  'teens': 1,
#  'greatest': 2,
#  'cause': 1,
#  'death': 1,
#  'amongst': 1,
#  'suicide': 1,
#  'killing': 1,
#  'first': 1,
#  'minority': 1,
#  'boys': 2,
#  'girls': 1,
#  'filled': 1,
#  'high': 1,
#  'hopeless': 1,
#  'nobodys': 3,
#  'care': 1,
#  'involved': 1,
#  'bother': 1,
#  'either': 2,
#  'hang': 1,
#  'kill': 1,
#  'americai': 1,
#  'betterand': 1,
#  'hills': 1,
#  'appalachia': 1,
#  'wish': 2,
#  'dignity': 2,
#  'cannot': 1,
#  'mines': 1,
#  'closed': 1,
#  'neither': 4,
#  'industry': 1,
#  'labor': 1,
#  'cared': 1,
#  'help': 8,
#  'unselfish': 1,
#  'black': 1,
#  'ghetto': 1,
#  'listening': 1,
#  'greater': 2,
#  'promises': 1,
#  'equality': 1,
#  'justice': 1,
#  'sit': 1,
#  'decaying': 1,
#  'schools': 1,
#  'huddled': 1,
#  'filthy': 1,
#  'rooms': 1,
#  'heat': 1,
#  'warding': 2,
#  'cold': 1,
#  'rats': 1,
#  'bound': 1,
#  'common': 1,
#  'urgent': 1,
#  'priority': 1,
#  'must': 2,
#  'begin': 2,
#  'disgrace': 1,
#  'tasks': 1,
#  'individuals': 1,
#  'even': 1,
#  'act': 1,
#  'erase': 1,
#  'material': 2,
#  'task': 1,
#  'satisfaction': 1,
#  'purpose': 1,
#  'afflicts': 1,
#  'seemed': 1,
#  'surrendered': 1,
#  'personal': 1,
#  'excellence': 1,
#  'community': 1,
#  'values': 1,
#  'mere': 1,
#  'accumulation': 1,
#  'things': 5,
#  'judge': 1,
#  'air': 1,
#  'pollution': 1,
#  'cigarette': 1,
#  'advertising': 1,
#  'ambulances': 1,
#  'clear': 4,
#  'highways': 1,
#  'carnage': 1,
#  'special': 1,
#  'locks': 1,
#  'doors': 1,
#  'jails': 1,
#  'break': 1,
#  'destruction': 1,
#  'redwood': 1,
#  'loss': 2,
#  'natural': 1,
#  'wonder': 2,
#  'chaotic': 1,
#  'sprawl': 1,
#  'napalm': 1,
#  'nuclear': 1,
#  'warheads': 1,
#  'armored': 1,
#  'cars': 1,
#  'police': 1,
#  'fight': 3,
#  'play': 3,
#  'include': 1,
#  'beauty': 1,
#  'poetry': 1,
#  'strength': 1,
#  'marriages': 1,
#  'intelligence': 1,
#  'debate': 1,
#  'integrity': 1,
#  'measures': 2,
#  'wit': 1,
#  'courage': 1,
#  'wisdom': 1,
#  'learning': 1,
#  'compassion': 1,
#  'devotion': 1,
#  'everything': 3,
#  'short': 1,
#  'except': 2,
#  'makes': 1,
#  'worthwhile': 1,
#  'elsewhere': 2,
#  'proudest': 1,
#  'boast': 1,
#  'jefferson': 1,
#  'would': 4,
#  'mankind': 2,
#  'still': 1,
#  'hold': 1,
#  'decent': 1,
#  'respect': 3,
#  'opinions': 1,
#  'opinion': 1,
#  'maintained': 1,
#  'descent': 1,
#  'athens': 1,
#  'forfeit': 1,
#  'sympathy': 1,
#  'ultimately': 2,
#  'security': 1,
#  'singleminded': 1,
#  'pursuit': 1,
#  'goals': 1,
#  'objectivesi': 1,
#  'americas': 2,
#  'interest': 1,
#  'simply': 1,
#  'withdraw': 1,
#  'raise': 2,
#  'flag': 2,
#  'surrender': 4,
#  'unacceptable': 5,
#  'presently': 1,
#  'following': 1,
#  'south': 20,
#  'number': 1,
#  'vietnamese': 5,
#  'cant': 1,
#  'period': 6,
#  'three': 4,
#  'struggle': 2,
#  'idea': 1,
#  'military': 7,
#  'every': 2,
#  'difficulties': 1,
#  'southeast': 2,
#  'asia': 2,
#  'response': 1,
#  'deal': 1,
#  'month': 2,
#  'dealt': 1,
#  'increase': 1,
#  'power': 1,
#  'kind': 1,
#  'feeling': 1,
#  'efforts': 1,
#  'sacrifice': 1,
#  'fighting': 2,
#  'several': 1,
#  'shown': 1,
#  'demonstrated': 1,
#  'association': 1,
#  'affiliation': 1,
#  'saigon': 5,
#  'destroy': 2,
#  'commander': 1,
#  'forces': 2,
#  'ben': 1,
#  'tre': 1,
#  'city': 2,
#  'save': 1,
#  'thirtyeight': 1,
#  'thousand': 1,
#  'wiped': 1,
#  'refugees': 1,
#  'commanders': 1,
#  'human': 1,
#  'room': 1,
#  'part': 4,
#  'decision': 1,
#  'longer': 1,
#  'write': 1,
#  'rome': 1,
#  'desert': 1,
#  'called': 1,
#  'go': 5,
#  'negotiating': 4,
#  'table': 4,
#  'steps': 1,
#  'negotiations': 3,
#  'possibility': 1,
#  'meaningful': 1,
#  'february': 3,
#  'opportunity': 1,
#  'existed': 1,
#  'administration': 1,
#  'felt': 1,
#  'victory': 2,
#  'corner': 1,
#  'sent': 1,
#  'ho': 1,
#  'chi': 1,
#  'minh': 1,
#  '8th': 1,
#  '1967': 1,
#  'virtually': 1,
#  'asking': 1,
#  'unconditional': 3,
#  'obtain': 2,
#  'north': 2,
#  'viet': 1,
#  'cong': 1,
#  'anymore': 1,
#  'negotiate': 4,
#  'compromises': 1,
#  'liberation': 3,
#  'front': 3,
#  'argue': 1,
#  'unfortunate': 1,
#  'lifewe': 1,
#  'choiceswe': 1,
#  'pull': 1,
#  'unilaterally': 1,
#  'second': 1,
#  'continue': 3,
#  'escalate': 1,
#  'bomb': 1,
#  'judgment': 1,
#  'nearer': 2,
#  'success': 1,
#  'third': 1,
#  'step': 1,
#  'achieve': 1,
#  'alternative': 1,
#  'role': 2,
#  'process': 2,
#  'elections': 1,
#  'determine': 1,
#  'decide': 1,
#  'tolerate': 1,
#  'corruption': 1,
#  'dishonesty': 1,
#  'draft': 3,
#  'eighteen': 1,
#  'nineteen': 1,
#  'die': 1,
#  'khe': 3,
#  'sanh': 2,
#  'eighteenyearolds': 1,
#  'nineteenyearolds': 1,
#  'feels': 1,
#  'que': 1,
#  'son': 1,
#  'demilitarized': 1,
#  'zone': 1,
#  'important': 2,
#  'san': 1,
#  'marines': 1,
#  'troops': 1,
#  'explanation': 1,
#  'killed': 1,
#  'weeks': 2,
#  'times': 2,
#  'soldiers': 1,
#  'casualties': 2,
#  'deaths': 1,
#  'height': 1,
#  'heavily': 1,
#  'compared': 1,
#  'carry': 1,
#  'burden': 1,
#  'elected': 1,
#  'kinds': 1,
#  'policies': 2,
#  'operation': 1,
#  'relationships': 1,
#  'countries': 1,
#  'globe': 3,
#  'campaigned': 1,
#  '1960': 1,
#  'talked': 1,
#  'prestige': 1,
#  'suffered': 1,
#  'present': 1,
#  'goes': 1,
#  'meeting': 1,
#  'oas': 1,
#  'montevideo': 3,
#  'travel': 2,
#  'latin': 1,
#  'stay': 1,
#  'base': 1,
#  'ships': 1,
#  'sea': 1,
#  'helicopters': 1,
#  'overhead': 1,
#  'ensure': 1,
#  'hes': 1,
#  'protected': 1,
#  'conditions': 1,
#  'freely': 1,
#  'clearly': 1,
#  'bases': 1,
#  'internally': 2,
#  'moment': 1,
#  'george': 1,
#  'bernard': 1,
#  'shaw': 1,
#  'dream': 1,
#  'months': 2,
#  'convention': 1,
#  'chicago': 1,
#  'assistance': 2,
#  'stands': 1,
#  'hand': 1,
#  'next': 2,
#  'november': 2,
#  'new': 1,
#  'generation': 1,
#  'plato': 1,
#  'livethank': 1,
#  'muchnxa0nsign': 1,
#  'dose': 2,
#  'inspirationevery': 1,
#  'week': 1,
#  'email': 1,
#  'favorite': 1,
#  'speeches': 1,
#  'essays': 1,
#  'poems': 1,
#  'ads': 1,
#  'sponsors': 1,
#  'spam': 1,
#  'nothing': 1,
#  'sale': 1,
#  'inspiration': 1,
#  'beautyclick': 1,
#  'sign': 1,
#  'upnn': 1}

# %%
# Finding word sequences in a dictionary ordered by frequency 
def SequenceSelection(dictionary, length, startindex = 0):
 
 # Check Input 
    if length > len(dictionary): 
        return print("input length is too long"); 
    else: 
        d = dictionary 
        items = [(v, k) for k, v in d.items()] 
        items.sort() 
        items.reverse() 
        itemsOut = [(k, v) for v, k in items] 

        highest = itemsOut[startindex:startindex + length] 
        dd = dict(highest) 
        wanted_keys = dd.keys() 
        dictshow = dict((k, d[k]) for k in wanted_keys if k in d) 
        return dictshow 
 
dictshow = SequenceSelection(dictionary = dict2, length = 7, startindex = 0)

# %%
dictshow
# Out:
# {'think': 46,
#  'united': 43,
#  'states': 43,
#  'going': 26,
#  'dont': 25,
#  'vietnam': 23,
#  'want': 21}

# %%
import matplotlib.pyplot as plt
dictionary = dictshow
plt.bar((dictionary.keys()), dictionary.values(), color='g')
plt.ylabel("frquency")          
plt.xlabel("words")           
plt.title("Most frequent words", {'fontsize' : 17})
plt.savefig("Most frequent words.png", transparent=True)
plt.show()

# %%
! pip install pysent3
# Out:
# Requirement already satisfied: pysent3 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: nltk>=2.0 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from pysent3) (3.7)
# Requirement already satisfied: pandas in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from pysent3) (1.4.2)
# Requirement already satisfied: tqdm in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from nltk>=2.0->pysent3) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from nltk>=2.0->pysent3) (2022.3.15)
# Requirement already satisfied: click in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from nltk>=2.0->pysent3) (8.0.4)
# Requirement already satisfied: joblib in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from nltk>=2.0->pysent3) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from pandas->pysent3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from pandas->pysent3) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from pandas->pysent3) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/youcefnazimtahari/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->pysent3) (1.16.0)

# %%
#import pysentiment as ps #<<-- seems like "pysentiment" package doesn't work anymore?
import pysent3 as ps

# %%
hiv4 = ps.HIV4() # Use Harvard IV
tokens = hiv4.tokenize(cleantext) # split string into constituents
score = hiv4.get_score(tokens) 
print(score)
# Out:
# {'Positive': 326, 'Negative': 252, 'Polarity': 0.12802768143939847, 'Subjectivity': 0.13580827064478188}

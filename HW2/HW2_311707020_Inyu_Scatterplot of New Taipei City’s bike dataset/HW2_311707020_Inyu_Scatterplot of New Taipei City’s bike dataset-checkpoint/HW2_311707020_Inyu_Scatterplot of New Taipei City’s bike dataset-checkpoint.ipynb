# %%
import requests
import json
import pprint
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import seaborn as sns
response = requests.get("https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json")
content = response.content
json_tree = json.loads(content)
pprint.pprint(json_tree)

for bike_rent_records in json_tree:
    leftRatio = float(bike_rent_records["sbi"]) / float(bike_rent_records["tot"]) * 100
    print("ID:{0} Left:{2:0.1f}% Name:{1}".format(bike_rent_records["sno"], bike_rent_records["aren"], leftRatio))

location= [i['sareaen'] for i in json_tree]
availbike =  np.array([int(i['tot'])for i in json_tree])-np.array([int(i['sbi'])for i in json_tree])

tb = pd.DataFrame({'District': location,'Available bike': availbike})
tb = df.groupby(by=["District"]).sum().reset_index()
tb
# Out:
# [{'act': '1',
#   'ar': '新北市新店區中正路700巷3號',
#   'aren': 'No. 3, Lane 700 Chung Cheng Road, Xindian District',
#   'bemp': '12',
#   'lat': '24.99116',
#   'lng': '121.53398',
#   'mday': '20220926213423',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '4',
#   'sna': '大鵬華城',
#   'snaen': 'Dapeng Community',
#   'sno': '1001',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '南昌街/新昌路口(西側廣場)',
#   'aren': 'Nanchang St./Xinchang Rd.',
#   'bemp': '28',
#   'lat': '25.068914',
#   'lng': '121.662748',
#   'mday': '20220926213445',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '1',
#   'sna': '汐止火車站',
#   'snaen': 'Xizhi Railway Station',
#   'sno': '1002',
#   'tot': '44'},
#  {'act': '1',
#   'ar': '新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)',
#   'aren': 'Sec. 1, Xintai 5th Rd./Ren’ai Rd.',
#   'bemp': '9',
#   'lat': '25.064162',
#   'lng': '121.658301',
#   'mday': '20220926213416',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '36',
#   'sna': '汐止區公所',
#   'snaen': 'Xizhi Dist. Office',
#   'sno': '1003',
#   'tot': '46'},
#  {'act': '1',
#   'ar': '建成路78號對面停車場',
#   'aren': 'No78, Jiancheng Rd',
#   'bemp': '19',
#   'lat': '25.07315',
#   'lng': '121.662555',
#   'mday': '20220926213437',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '29',
#   'sna': '國泰綜合醫院',
#   'snaen': 'Cathay General Hospital',
#   'sno': '1004',
#   'tot': '48'},
#  {'act': '1',
#   'ar': '中興路三段224號(對面)',
#   'aren': 'No. 224, Sec. 3, Zhongxing Rd., Xindian Dist.(opposite)',
#   'bemp': '33',
#   'lat': '24.982830',
#   'lng': '121.543620',
#   'mday': '20220926213422',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '12',
#   'sna': '捷運大坪林站(5號出口)',
#   'snaen': 'MRT DaPingLin Station(Exit.5)',
#   'sno': '1006',
#   'tot': '78'},
#  {'act': '1',
#   'ar': '大同路二段184巷/龍安路202巷(西側)(汐科火車站北站出口前)',
#   'aren': 'Ln. 184,Sec. 2, Datong Rd./Ln. 202,Long’an Rd.',
#   'bemp': '12',
#   'lat': '25.064106',
#   'lng': '121.653019',
#   'mday': '20220926213440',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '14',
#   'sna': '汐科火車站(北)',
#   'snaen': 'Xike Railway Station(North)',
#   'sno': '1007',
#   'tot': '26'},
#  {'act': '1',
#   'ar': '重陽路一段120巷/中華路2巷',
#   'aren': 'Ln. 120, Sec. 1, Chongyang Rd./Ln. 2, Zhonghua Rd.',
#   'bemp': '30',
#   'lat': '25.060125',
#   'lng': '121.483101',
#   'mday': '20220926213417',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '10',
#   'sna': '興華公園',
#   'snaen': 'Xinghua Park',
#   'sno': '1008',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '集美街/重新路四段184巷',
#   'aren': 'Jimei St., Sanchong Dist./Ln. 184, Sec. 4, Chongxin Rd.',
#   'bemp': '41',
#   'lat': '25.054391',
#   'lng': '121.488489',
#   'mday': '20220926213443',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '23',
#   'sna': '三重國民運動中心',
#   'snaen': 'San chong Civil Sports Center',
#   'sno': '1009',
#   'tot': '68'},
#  {'act': '1',
#   'ar': '捷運路/捷運路37巷',
#   'aren': 'Jieyun Rd./Ln. 37, Jieyun Rd.',
#   'bemp': '16',
#   'lat': '25.055883',
#   'lng': '121.484739',
#   'mday': '20220926213421',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '8',
#   'sna': '捷運三重站(3號出口)',
#   'snaen': 'MRT Sanchong Sta. (Exit 3)',
#   'sno': '1010',
#   'tot': '24'},
#  {'act': '1',
#   'ar': '樟樹二路/樟樹一路141巷',
#   'aren': 'Zhangshu 2nd Rd./Ln. 141, Zhangshu 1st Rd.',
#   'bemp': '18',
#   'lat': '25.066688',
#   'lng': '121.640367',
#   'mday': '20220926213437',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '21',
#   'sna': '樟樹國小',
#   'snaen': 'Zhangshu Elementary School',
#   'sno': '1011',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '中興路/民族六街',
#   'aren': 'Zhongxing Rd./Minzu 6th St.',
#   'bemp': '15',
#   'lat': '25.0688',
#   'lng': '121.628908',
#   'mday': '20220926213431',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '26',
#   'sna': '金龍國小',
#   'snaen': 'Jinlong Elementary School',
#   'sno': '1012',
#   'tot': '42'},
#  {'act': '1',
#   'ar': '民權街二段90號',
#   'aren': 'No.90, Sec. 2, Minquan St.',
#   'bemp': '10',
#   'lat': '25.047578',
#   'lng': '121.618888',
#   'mday': '20220926213428',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '6',
#   'sna': '白雲國小',
#   'snaen': 'Pai Yun Primary School',
#   'sno': '1013',
#   'tot': '16'},
#  {'act': '1',
#   'ar': '東勢街/芳園街',
#   'aren': 'Dongshi St./Fangyuan St.',
#   'bemp': '15',
#   'lat': '25.039031',
#   'lng': '121.624333',
#   'mday': '20220926213424',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '14',
#   'sna': '東勢宜興活動中心',
#   'snaen': 'Yixing-Dongshi Civic Center',
#   'sno': '1014',
#   'tot': '30'},
#  {'act': '1',
#   'ar': '建安街/建安街57巷',
#   'aren': 'Ln. 57, Jian’an St./Jian’an St.',
#   'bemp': '21',
#   'lat': '25.025358',
#   'lng': '121.428348',
#   'mday': '20220926213432',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '13',
#   'sna': '後港公園',
#   'snaen': 'Hougang Park',
#   'sno': '1015',
#   'tot': '34'},
#  {'act': '1',
#   'ar': '四維路17號-20號',
#   'aren': 'No.17, Siwei Rd./No.20, Siwei Rd.',
#   'bemp': '20',
#   'lat': '25.0241250',
#   'lng': '121.423870',
#   'mday': '20220926213437',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '13',
#   'sna': '福營行政中心',
#   'snaen': 'Fuying Administration Center',
#   'sno': '1016',
#   'tot': '34'},
#  {'act': '1',
#   'ar': '新莊區西盛街/西盛街201巷',
#   'aren': 'Xisheng St./Ln. 201, Xisheng St.',
#   'bemp': '14',
#   'lat': '25.017113',
#   'lng': '121.428048',
#   'mday': '20220926213420',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '22',
#   'sna': '西盛公園',
#   'snaen': 'Xisheng Park',
#   'sno': '1017',
#   'tot': '36'},
#  {'act': '1',
#   'ar': '北新路二段/北新路二段97巷',
#   'aren': 'Sec. 2, Beixin Rd./Ln. 97, Sec. 2, Beixin Rd.',
#   'bemp': '20',
#   'lat': '24.974272',
#   'lng': '121.542779',
#   'mday': '20220926213438',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '0',
#   'sna': '忠誠里(北新路2段97巷)',
#   'snaen': 'Zhongcheng Village (Ln. 97, Sec. 2, Beixin Rd)',
#   'sno': '1018',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '民權路139號旁',
#   'aren': 'No.139, Minquan Rd.',
#   'bemp': '38',
#   'lat': '25.090565',
#   'lng': '121.471621',
#   'mday': '20220926213429',
#   'sarea': '蘆洲區',
#   'sareaen': 'Luzhou Dist.',
#   'sbi': '12',
#   'sna': '仁愛廣場',
#   'snaen': 'Renai Square',
#   'sno': '1019',
#   'tot': '50'},
#  {'act': '1',
#   'ar': '中正北路/三民街175巷',
#   'aren': 'Zhongzheng N. Rd./Ln. 175, Sanmin St.',
#   'bemp': '13',
#   'lat': '25.066245 ',
#   'lng': '121.484337 ',
#   'mday': '20220926213429',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '0',
#   'sna': '重陽國小',
#   'snaen': 'Chong Yang Elementary School',
#   'sno': '1020',
#   'tot': '36'},
#  {'act': '1',
#   'ar': '中正北路107號',
#   'aren': 'No.107, Zhongzheng N. Rd',
#   'bemp': '38',
#   'lat': '25.063396',
#   'lng': '121.488982',
#   'mday': '20220926213423',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '12',
#   'sna': '明志國中',
#   'snaen': 'Mingzhi Junior High School',
#   'sno': '1021',
#   'tot': '50'},
#  {'act': '1',
#   'ar': '中正北路/中正北路276巷',
#   'aren': 'Ln. 276, Zhongzheng N. Rd.',
#   'bemp': '42',
#   'lat': '25.068681',
#   'lng': '121.480705',
#   'mday': '20220926213434',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '21',
#   'sna': '三重商工',
#   'snaen': 'San-Chung Commercial and Industrial Vocational High School',
#   'sno': '1022',
#   'tot': '64'},
#  {'act': '1',
#   'ar': '中正路/中華路一段(鄰近新莊廟街)',
#   'aren': 'Zhongzheng Rd./Sec. 1, Zhonghua Rd.',
#   'bemp': '44',
#   'lat': '25.036152 ',
#   'lng': '121.452069 ',
#   'mday': '20220926213416',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '0',
#   'sna': '捷運新莊站(1號出口)',
#   'snaen': 'MRT Xinzhuang Sta. (Exit 1)',
#   'sno': '1023',
#   'tot': '58'},
#  {'act': '1',
#   'ar': '原興路/中興路150巷',
#   'aren': 'Yuanxing Rd./Ln. 150, Zhongxing Rd.',
#   'bemp': '16',
#   'lat': '25.065042',
#   'lng': '121.633149',
#   'mday': '20220926213444',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '16',
#   'sna': '原興廣場',
#   'snaen': 'Yuan Xing Square',
#   'sno': '1024',
#   'tot': '32'},
#  {'act': '1',
#   'ar': '水源路二段42號訖水源路二段68號',
#   'aren': 'No.42 to No.68, Sec. 2, Shuiyuan Rd.',
#   'bemp': '26',
#   'lat': '25.056875',
#   'lng': '121.655207',
#   'mday': '20220926213422',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '42',
#   'sna': '文化白雲公園',
#   'snaen': 'Wenhua-Baiyun Park',
#   'sno': '1025',
#   'tot': '68'},
#  {'act': '1',
#   'ar': '更生街/自立路(西南側)',
#   'aren': 'Gengsheng St./Zili Rd.',
#   'bemp': '16',
#   'lat': '24.996151 ',
#   'lng': '121.521988 ',
#   'mday': '20220926213438',
#   'sarea': '中和區',
#   'sareaen': 'Zhonghe Dist.',
#   'sbi': '30',
#   'sna': '秀山國小',
#   'snaen': 'Xiushan Elementary School',
#   'sno': '1026',
#   'tot': '46'},
#  {'act': '1',
#   'ar': '中安街/中和路378巷(東南側)',
#   'aren': 'Zhong’an St./Ln. 378, Zhonghe Rd.',
#   'bemp': '44',
#   'lat': '25.001013 ',
#   'lng': '121.511588 ',
#   'mday': '20220926213436',
#   'sarea': '中和區',
#   'sareaen': 'Zhonghe Dist.',
#   'sbi': '6',
#   'sna': '捷運永安市場站',
#   'snaen': 'MRT Yongan Market Sta.',
#   'sno': '1027',
#   'tot': '50'},
#  {'act': '1',
#   'ar': '仁愛路/保生路(鄰近世界宗教博物館)',
#   'aren': 'Ren’ai Rd./Baosheng Rd.',
#   'bemp': '21',
#   'lat': '25.009838',
#   'lng': '121.505825',
#   'mday': '20220926213431',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist.',
#   'sbi': '39',
#   'sna': '仁愛公園',
#   'snaen': 'Renai Park',
#   'sno': '1029',
#   'tot': '60'},
#  {'act': '1',
#   'ar': '安樂路/得和路(西南側)',
#   'aren': 'Anle Rd./Dehe Rd.',
#   'bemp': '14',
#   'lat': '25.000726 ',
#   'lng': '121.514350 ',
#   'mday': '20220926213441',
#   'sarea': '中和區',
#   'sareaen': 'Zhonghe Dist.',
#   'sbi': '23',
#   'sna': '中和公園',
#   'snaen': 'Zhonghe Park',
#   'sno': '1030',
#   'tot': '38'},
#  {'act': '1',
#   'ar': '湖前街31巷2弄/湖前街31巷',
#   'aren': 'Aly. 2, Ln. 31, Huqian St./Ln. 31, Huqian St.',
#   'bemp': '20',
#   'lat': '25.069473',
#   'lng': '121.631525 ',
#   'mday': '20220926213432',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '24',
#   'sna': '金龍公園',
#   'snaen': 'Jinlong Park',
#   'sno': '1031',
#   'tot': '44'},
#  {'act': '1',
#   'ar': '集賢路221巷重陽活動中心(鄰近蘆洲兒童親子分館)',
#   'aren': 'Ln. 221, Jixian Rd.',
#   'bemp': '16',
#   'lat': '25.085688',
#   'lng': '121.483618',
#   'mday': '20220926213416',
#   'sarea': '蘆洲區',
#   'sareaen': 'Luzhou Dist.',
#   'sbi': '28',
#   'sna': '重陽公園',
#   'snaen': 'Chong Yang Park',
#   'sno': '1032',
#   'tot': '50'}]
# ID:1001 Left:20.0% Name:No. 3, Lane 700 Chung Cheng Road, Xindian District
# ID:1002 Left:2.3% Name:Nanchang St./Xinchang Rd.
# ID:1003 Left:78.3% Name:Sec. 1, Xintai 5th Rd./Ren’ai Rd.
# ID:1004 Left:60.4% Name:No78, Jiancheng Rd
# ID:1006 Left:15.4% Name:No. 224, Sec. 3, Zhongxing Rd., Xindian Dist.(opposite)
# ID:1007 Left:53.8% Name:Ln. 184,Sec. 2, Datong Rd./Ln. 202,Long’an Rd.
# ID:1008 Left:25.0% Name:Ln. 120, Sec. 1, Chongyang Rd./Ln. 2, Zhonghua Rd.
# ID:1009 Left:33.8% Name:Jimei St., Sanchong Dist./Ln. 184, Sec. 4, Chongxin Rd.
# ID:1010 Left:33.3% Name:Jieyun Rd./Ln. 37, Jieyun Rd.
# ID:1011 Left:52.5% Name:Zhangshu 2nd Rd./Ln. 141, Zhangshu 1st Rd.
# ID:1012 Left:61.9% Name:Zhongxing Rd./Minzu 6th St.
# ID:1013 Left:37.5% Name:No.90, Sec. 2, Minquan St.
# ID:1014 Left:46.7% Name:Dongshi St./Fangyuan St.
# ID:1015 Left:38.2% Name:Ln. 57, Jian’an St./Jian’an St.
# ID:1016 Left:38.2% Name:No.17, Siwei Rd./No.20, Siwei Rd.
# ID:1017 Left:61.1% Name:Xisheng St./Ln. 201, Xisheng St.
# ID:1018 Left:0.0% Name:Sec. 2, Beixin Rd./Ln. 97, Sec. 2, Beixin Rd.
# ID:1019 Left:24.0% Name:No.139, Minquan Rd.
# ID:1020 Left:0.0% Name:Zhongzheng N. Rd./Ln. 175, Sanmin St.
# ID:1021 Left:24.0% Name:No.107, Zhongzheng N. Rd
# ID:1022 Left:32.8% Name:Ln. 276, Zhongzheng N. Rd.
# ID:1023 Left:0.0% Name:Zhongzheng Rd./Sec. 1, Zhonghua Rd.
# ID:1024 Left:50.0% Name:Yuanxing Rd./Ln. 150, Zhongxing Rd.
# ID:1025 Left:61.8% Name:No.42 to No.68, Sec. 2, Shuiyuan Rd.
# ID:1026 Left:65.2% Name:Gengsheng St./Zili Rd.
# ID:1027 Left:12.0% Name:Zhong’an St./Ln. 378, Zhonghe Rd.
# ID:1029 Left:65.0% Name:Ren’ai Rd./Baosheng Rd.
# ID:1030 Left:60.5% Name:Anle Rd./Dehe Rd.
# ID:1031 Left:54.5% Name:Aly. 2, Ln. 31, Huqian St./Ln. 31, Huqian St.
# ID:1032 Left:56.0% Name:Ln. 221, Jixian Rd.
#           District  Available bike
# 0     Luzhou Dist.              59
# 1   Sanchong Dist.             210
# 2    Xindian Dist.             103
# 3  Xinzhuang Dist.             116
# 4      Xizhi Dist.             208
# 5     Yonghe Dist.              21
# 6    Zhonghe Dist.              74

# %%
dist= tb['District'].values
availbike= tb['Available bike'].values

aa = sns.scatterplot(data=tb, x="District", y="Available bike")
aa.set_title('Scatter Chart')
# Out:
# Text(0.5, 1.0, 'Scatter Chart')

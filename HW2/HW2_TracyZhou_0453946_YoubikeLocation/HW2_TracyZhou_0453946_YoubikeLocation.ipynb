# %%
"""
Created on Thu Sep 22 16:15:46 2022

@author: Tracy Zhou

[Mandatory]
HW2: Try web scraping with Taiwan’s bike dataset
Description: Please use Taiwan’s bike dataset to draw scatter plot. You can decide which region, which kind of bike (the common one in Taiwan is Ubike) and the objective of the analysis.
Here are some examples:
Draw the scatter plot among the number of bikes in Xinbei Citu
Map the u-bike station in Taipei with the number of u-bike left at that station
"""


import pandas as pd
import requests
import json
import folium

# %%
# download the ubike data of Hsinchu from https://data.gov.tw/dataset/67781
response = requests.get("http://odws.hccg.gov.tw/001/Upload/25/OpenData/9059/59/67e94b18-b8ba-4c6a-9a2a-e66638a31895.json")
content = response.content
json_tree = json.loads(content)

# data precess
data = pd.DataFrame(json_tree)
data = data.rename(columns={"站點名稱": "Site Name", 
                   "經度": "Longitude", 
                   "緯度": "Latitude", 
                   "圖片URL": "URL", 
                   "站點位置": "Site Address"})
# data : 63 rows × 5 columns

data
# Out:
#     Site Name   Longitude   Latitude  \
# 0   新竹火車站(前站)  120.971459  24.801815
# 1        東門圓環  120.970556  24.803866
# 2       新竹市政府   120.96926  24.806138
# 3   明志書院立體停車場   120.96576   24.80167
# 4     辛志平校長故居  120.973662  24.804317
# ..        ...         ...        ...
# 58  力行一路力行六路口    121.0155   24.77395
# 59         聯園   121.01915   24.76807
# 60  園區三路研新一路口   120.99512   24.77678
# 61       同業公會   121.00198   24.78228
# 62    興業二路停車場   120.98996   24.77872
#
#                                                   URL       Site Address F6 F7
# 0   http://opendata-manage.hccg.gov.tw/img/24/youb...  中華路二段445號(火車站前廣場)
# 1   http://opendata-manage.hccg.gov.tw/img/24/youb...     勝利路2號(對面圓環人行道)
# 2   http://opendata-manage.hccg.gov.tw/img/24/youb...     中央路106號(對面人行道)
# 3   http://opendata-manage.hccg.gov.tw/img/24/youb...   西大路317號(停車場前人行道)
# 4   http://opendata-manage.hccg.gov.tw/img/24/youb...      東門街32號(汽車停車場)
# ..                                                ...                ... .. ..
# 58  http://opendata-manage.hccg.gov.tw/img/24/youb...     力行一路/力行六路口(北側)
# 59  http://opendata-manage.hccg.gov.tw/img/24/youb...     力行三路/力行二路口(北側)
# 60  http://opendata-manage.hccg.gov.tw/img/24/youb...    研新一路/園區三路口(西北側)
# 61  http://opendata-manage.hccg.gov.tw/img/24/youb...       展業一路/新安路(北側)
# 62  http://opendata-manage.hccg.gov.tw/img/24/youb...     興業二路/研新三路口(西側)
#
# [63 rows x 7 columns]

# %%
# Set the ceter of our map : NYCU managemant building 
# hsinchu_coords = [24.8138, 120.9675]
# NYCU Location: [24.787178345630263, 120.99748615357079]
Location_coords = [24.7871, 120.9974]
#Create the map
my_map = folium.Map(location = Location_coords, zoom_start = 13)

for i in range(0, 63):
  folium.Marker([data['Latitude'][i], data['Longitude'][i]], 
                popup = "Site name: " + data['Site Name'][i]). add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b9e7831d00dc6f5a94e9aeab025af68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b9e7831d00dc6f5a94e9aeab025af68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1b9e7831d00dc6f5a94e9aeab025af68 = L.map(
#                 &quot;map_1b9e7831d00dc6f5a94e9aeab025af68&quot;,
#                 {
#                     center: [24.7871, 120.9974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4eda3d94596af67e04a8f29bc045a0ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#             var marker_716d5b4998bf0e27b9d9542253e94ec4 = L.marker(
#                 [24.801815, 120.971459],
#                 {}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#         var popup_313412a00d737f74dc04cbc103bd414f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4d1a60078ef3f284e9a4f4939dff1320 = $(`&lt;div id=&quot;html_4d1a60078ef3f284e9a4f4939dff1320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: 新竹火車站(前站)&lt;/div&gt;`)[0];
#             popup_313412a00d737f74dc04cbc103bd414f.setContent(html_4d1a60078ef3f284e9a4f4939dff1320);
#
#
#         marker_716d5b4998bf0e27b9d9542253e94ec4.bindPopup(popup_313412a00d737f74dc04cbc103bd414f)
#         ;
#
#
#
#
#             var marker_056d1ad7cb967deaf39b9d5393cacb75 = L.marker(
#                 [24.803866, 120.970556],
#                 {}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#         var popup_68006725734385aff4b5c2c571edeb07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d524a1bad2744b94f40a399be4add260 = $(`&lt;div id=&quot;html_d524a1bad2744b94f40a399be4add260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: 東門圓環&lt;/div&gt;`)[0];
#             popup_68006725734385aff4b5c2c571edeb07.setContent(html_d524a1bad2744b94f40a399be4add260);
#
#
#         marker_056d1ad7cb967deaf39b9d5393cacb75.bindPopup(popup_68006725734385aff4b5c2c571edeb07)
#         ;
#
#
#
#
#             var marker_6433499818dfe818e525293a95fb0c26 = L.marker(
#                 [24.806138, 120.96926],
#                 {}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#         var popup_d7482a90186b18aa42ed653330d0b60c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_109d165a3bd8d60d30e28ed6c6a90e05 = $(`&lt;div id=&quot;html_109d165a3bd8d60d30e28ed6c6a90e05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: 新竹市政府&lt;/div&gt;`)[0];
#             popup_d7482a90186b18aa42ed653330d0b60c.setContent(html_109d165a3bd8d60d30e28ed6c6a90e05);
#
#
#         marker_6433499818dfe818e525293a95fb0c26.bindPopup(popup_d7482a90186b18aa42ed653330d0b60c)
#         ;
#
#
#
#
#             var marker_75538098daab64435a9a57e6da956f4c = L.marker(
#                 [24.80167, 120.96576],
#                 {}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#         var popup_4bc8fd08653237d334de91dead355f88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_25fbbb152d3ff7ee58b197001fad6dea = $(`&lt;div id=&quot;html_25fbbb152d3ff7ee58b197001fad6dea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: 明志書院立體停車場&lt;/div&gt;`)[0];
#             popup_4bc8fd08653237d334de91dead355f88.setContent(html_25fbbb152d3ff7ee58b197001fad6dea);
#
#
#         marker_75538098daab64435a9a57e6da956f4c.bindPopup(popup_4bc8fd08653237d334de91dead355f88)
#         ;
#
#
#
#
#             var marker_ef97ecf3eade8701f8dc4699496ec9aa = L.marker(
#                 [24.804317, 120.973662],
#                 {}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#         var popup_f7f7e9a83cf6e12a7bac14e87bf28802 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6501245b6435ed210ccb6464fc9def3b = $(`&lt;div id=&quot;html_6501245b6435ed210ccb6464fc9def3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: 辛志平校長故居&lt;/div&gt;`)[0];
#             popup_f7f7e9a83cf6e12a7bac14e87bf28802.setContent(html_6501245b6435ed210ccb6464fc9def3b);
#
#
#         marker_ef97ecf3eade8701f8dc4699496ec9aa.bindPopup(popup_f7f7e9a83cf6e12a7bac14e87bf28802)
#         ;
#
#
#
#
#             var marker_fdeb8741ef183cb62a67a31e5e3d3fe8 = L.marker(
#                 [24.808979, 120.967098],
#                 {}
#             ).addTo(map_1b9e7831d00dc6f5a94e9aeab025af68);
#
#
#         var popup_0ad22c91a948d220856ae05866c8ae9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5ba32cf1c9cf12ed0950e9b82bce4d48 = $(`&lt;div id=&quot;html_5ba32cf1c9cf1

# %%
# Taipei Youbike 

response = requests.get("https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json")
content = response.content
json_tree = json.loads(content)
#pprint.pprint(json_tree[1])
# sno：站點代號、 sna：場站名稱(中文)、 tot：場站總停車格、 sbi：場站目前車輛數量、 sarea：場站區域(中文)、 mday：資料更新時間、 
# lat：緯度、 lng：經度、 
# ar：地(中文)、 sareaen：場站區域(英文)、 snaen：場站名稱(英文)、 aren：地址(英文)、 bemp：空位數量、 act：全站禁用狀態

data = pd.DataFrame(json_tree, columns = ['sna', 'lng', 'lat', 'tot','sbi','bemp','act'])
data = data.rename(columns={"sna": "SiteName", "lng": "Longitude", "lat": "Latitude", "sbi": "Remaining"})
# data : 1168 rows × 3 columns

data
# Out:
#                       SiteName  Longitude  Latitude  tot  Remaining  bemp act
# 0           YouBike2.0_捷運科技大樓站  121.54360  25.02605   28          2    25   1
# 1       YouBike2.0_復興南路二段273號前  121.54357  25.02565   22          3    18   1
# 2         YouBike2.0_國北教大實小東側門  121.54124  25.02429   16          0    16   1
# 3            YouBike2.0_和平公園東側  121.54282  25.02351   11          0    11   1
# 4         YouBike2.0_辛亥復興路口西北側  121.54299  25.02153   16          1    15   1
# ...                        ...        ...       ...  ...        ...   ...  ..
# 1163      YouBike2.0_臺大總圖書館西南側  121.54031  25.01690   30          4    26   1
# 1164        YouBike2.0_臺大黑森林西側  121.54347  25.01995   20          1    19   1
# 1165        YouBike2.0_臺大獸醫館南側  121.54242  25.01791   24          0    24   1
# 1166      YouBike2.0_臺大新體育館東南側  121.53591  25.02112   40          6    33   1
# 1167  YouBike2.0_臺大明達館北側(員工宿舍)  121.54469  25.01816   18          0    18   1
#
# [1168 rows x 7 columns]

# %%
# Define coordinates of where we want to center our map
# hsinchu_coords = [24.8138, 120.9675]
# NYCU Location: [24.787178345630263, 120.99748615357079]
# 台大管院 = [25.014138089260964, 121.5379950959105]
Location_coords = [25.0141, 121.5379]
#Create the map
my_map = folium.Map(location = Location_coords, zoom_start = 17)

for i in range(0, 1168):
  folium.Marker([data['Latitude'][i], data['Longitude'][i]], 
                popup = "Site name: " + data['SiteName'][i]). add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c8da715569c7724215e4a5ff46f571f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c8da715569c7724215e4a5ff46f571f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c8da715569c7724215e4a5ff46f571f = L.map(
#                 &quot;map_1c8da715569c7724215e4a5ff46f571f&quot;,
#                 {
#                     center: [25.0141, 121.5379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6079463e5ade303d27e5242761a2bc63 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#             var marker_c2bc24a7ad4e5363d467f52c808eab35 = L.marker(
#                 [25.02605, 121.5436],
#                 {}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#         var popup_dd662b5a983960cc295e2644b36d3d72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4608bd5d54dbb09946fed780d70dc273 = $(`&lt;div id=&quot;html_4608bd5d54dbb09946fed780d70dc273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: YouBike2.0_捷運科技大樓站&lt;/div&gt;`)[0];
#             popup_dd662b5a983960cc295e2644b36d3d72.setContent(html_4608bd5d54dbb09946fed780d70dc273);
#
#
#         marker_c2bc24a7ad4e5363d467f52c808eab35.bindPopup(popup_dd662b5a983960cc295e2644b36d3d72)
#         ;
#
#
#
#
#             var marker_c3cc0adceb6f8ae14a7ff75c0bba62de = L.marker(
#                 [25.02565, 121.54357],
#                 {}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#         var popup_c830bb196c1ad82ccd9e9e6aa5851c67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6a1dd5c3c7ebca27eb160a1f5ddcda63 = $(`&lt;div id=&quot;html_6a1dd5c3c7ebca27eb160a1f5ddcda63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: YouBike2.0_復興南路二段273號前&lt;/div&gt;`)[0];
#             popup_c830bb196c1ad82ccd9e9e6aa5851c67.setContent(html_6a1dd5c3c7ebca27eb160a1f5ddcda63);
#
#
#         marker_c3cc0adceb6f8ae14a7ff75c0bba62de.bindPopup(popup_c830bb196c1ad82ccd9e9e6aa5851c67)
#         ;
#
#
#
#
#             var marker_252abae921e0cfaa1f919117defcfd04 = L.marker(
#                 [25.02429, 121.54124],
#                 {}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#         var popup_599566c8e08b090c2a031d7d345b707c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ae8d8ae1192a7d8f40fffd9ba1038a78 = $(`&lt;div id=&quot;html_ae8d8ae1192a7d8f40fffd9ba1038a78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: YouBike2.0_國北教大實小東側門&lt;/div&gt;`)[0];
#             popup_599566c8e08b090c2a031d7d345b707c.setContent(html_ae8d8ae1192a7d8f40fffd9ba1038a78);
#
#
#         marker_252abae921e0cfaa1f919117defcfd04.bindPopup(popup_599566c8e08b090c2a031d7d345b707c)
#         ;
#
#
#
#
#             var marker_95e44d7ae2c40ca14d781f0797a6a021 = L.marker(
#                 [25.02351, 121.54282],
#                 {}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#         var popup_606624b32481efc7b0ea42862de8562c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ba6b3b03e371f3babd86cb624ffa972f = $(`&lt;div id=&quot;html_ba6b3b03e371f3babd86cb624ffa972f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: YouBike2.0_和平公園東側&lt;/div&gt;`)[0];
#             popup_606624b32481efc7b0ea42862de8562c.setContent(html_ba6b3b03e371f3babd86cb624ffa972f);
#
#
#         marker_95e44d7ae2c40ca14d781f0797a6a021.bindPopup(popup_606624b32481efc7b0ea42862de8562c)
#         ;
#
#
#
#
#             var marker_f8dfa3b175ebd7cc8dd3c4f06898aaf1 = L.marker(
#                 [25.02153, 121.54299],
#                 {}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#         var popup_e87e4441b38246bae46be7ced2a895c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4a6ae7cfbfcfc512074e5ad5cc9fa369 = $(`&lt;div id=&quot;html_4a6ae7cfbfcfc512074e5ad5cc9fa369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site name: YouBike2.0_辛亥復興路口西北側&lt;/div&gt;`)[0];
#             popup_e87e4441b38246bae46be7ced2a895c5.setContent(html_4a6ae7cfbfcfc512074e5ad5cc9fa369);
#
#
#         marker_f8dfa3b175ebd7cc8dd3c4f06898aaf1.bindPopup(popup_e87e4441b38246bae46be7ced2a895c5)
#         ;
#
#
#
#
#             var marker_e00fa19bdff39234211ea7d60dbbeefa = L.marker(
#                 [25.02429, 121.54328],
#                 {}
#             ).addTo(map_1c8da715569c7724215e4a5ff46f571f);
#
#
#         var popup_5e0fef3b96e2aee9fd9bceb1f43a6a02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_87a1d63c8d0cce27f336

# %%
# Ramaining bicycles around me 

my_map = folium.Map(location = Location_coords, zoom_start = 16.4, tiles='Stamen Toner')

# data = data[(data.lat > 25.01) & (data.lat < 25.02) & (data.lng > 121.53) & (data.lng < 121.54) ]
data = data[data.Remaining > 0]

from folium import plugins
bike = plugins.MarkerCluster().add_to(my_map)

for lat, lng, label, in zip(data.Latitude, data.Longitude, data.Remaining):
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color='green', prefix='fa', icon='bicycle'),
        popup=label,
    ).add_to(bike)
# add incidents to map

folium.Circle(radius=500, location=[25.0141, 121.5379], popup='NTU Finance', color='crimson', fill=True,).add_to(my_map)
folium.Marker([25.0141, 121.5379], popup='NTU Finance', 
              icon=folium.Icon(color='red', prefix='fa', icon='user')).add_to(my_map)

my_map.add_child(bike)


"""
## save the image 

my_map.save('mymap.html')
from html2image import Html2Image
hti = Html2Image()
hti.screenshot(
    html_file='mymap.html',
    save_as='Bike_map.png'
)
"""
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b3bfd65d2b8f94e829aa12b5d8ed2e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b3bfd65d2b8f94e829aa12b5d8ed2e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2b3bfd65d2b8f94e829aa12b5d8ed2e9 = L.map(
#                 &quot;map_2b3bfd65d2b8f94e829aa12b5d8ed2e9&quot;,
#                 {
#                     center: [25.0141, 121.5379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68c1ebe333d3779e966c973e2b648060 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2b3bfd65d2b8f94e829aa12b5d8ed2e9);
#
#
#             var marker_cluster_31bb02c3fecb7d10c80e9329908c03ec = L.markerClusterGroup(
#                 {}
#             );
#             map_2b3bfd65d2b8f94e829aa12b5d8ed2e9.addLayer(marker_cluster_31bb02c3fecb7d10c80e9329908c03ec);
#
#
#             var marker_94e3be2c10c2ed9c2e0e24671ae302bb = L.marker(
#                 [25.02605, 121.5436],
#                 {}
#             ).addTo(marker_cluster_31bb02c3fecb7d10c80e9329908c03ec);
#
#
#             var icon_42544c76f4215aefff9e6d8cd14ebb1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_94e3be2c10c2ed9c2e0e24671ae302bb.setIcon(icon_42544c76f4215aefff9e6d8cd14ebb1a);
#
#
#         var popup_533be804c6ca4b1454481ac54fec2c3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_59df4af0d5e942e10949b20019c29326 = $(`&lt;div id=&quot;html_59df4af0d5e942e10949b20019c29326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_533be804c6ca4b1454481ac54fec2c3d.setContent(html_59df4af0d5e942e10949b20019c29326);
#
#
#         marker_94e3be2c10c2ed9c2e0e24671ae302bb.bindPopup(popup_533be804c6ca4b1454481ac54fec2c3d)
#         ;
#
#
#
#
#             var marker_0d5d2d71cc5d81d6cd6be5ae1b0fa188 = L.marker(
#                 [25.02565, 121.54357],
#                 {}
#             ).addTo(marker_cluster_31bb02c3fecb7d10c80e9329908c03ec);
#
#
#             var icon_9570da4738c3619fd2447cd1575489fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0d5d2d71cc5d81d6cd6be5ae1b0fa188.setIcon(icon_9570da4738c3619fd2447cd1575489fd);
#
#
#         var popup_5aab0ba9f2a9c4dd8d60f080329ad9ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cf83dc9ff8de44199e0dc8d58bb78769 = $(`&lt;div id=&quot;html_cf83dc9ff8de44199e0dc8d58bb78769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#             popup_5aab0ba9f2a9c4dd8d60f080329ad9ba.setContent(html_cf83dc9ff8de44199e0dc8d58bb78769);
#
#
#         marker_0d5d2d71cc5d81d6cd6be5ae1b0fa188.bindPopup(popup_5aab0ba9f2a9c4dd8d60f080329ad9ba)
#         ;
#
#
#
#
#             var marker_6e9e591af603fe456e320f0e37f0645e = L.marker(
#                 [25.02153, 121.54299],
#                 {}
#             ).addTo(marker_cluster_31bb02c3fecb7d10c80e9329908c03ec);
#
#
#             var icon_d783321bc9d481a28fc6ac30f0237427 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6e9e591af603fe456e320f0e37f0645e.setIcon(icon_d783321bc9d481a28fc6ac30f0237427);
#
#
#         var popup_c181f5a6798bf12212bfd2158c599bdd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b4e050841efea73a89d36ad8da390779 = $(`&lt;div id=&quot;html_b4e050841efea73a89d36ad8da390779&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
response = requests.get('https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json')
content = response.content
data = pd.read_json(content)
data.head()
# Out:
#          sno                     sna  tot  sbi sarea                 mday  \
# 0  500101001      YouBike2.0_捷運科技大樓站   28    1   大安區  2022-09-30 15:09:39
# 1  500101002  YouBike2.0_復興南路二段273號前   22    1   大安區  2022-09-30 15:09:13
# 2  500101003    YouBike2.0_國北教大實小東側門   16   13   大安區  2022-09-30 15:07:12
# 3  500101004       YouBike2.0_和平公園東側   11    0   大安區  2022-09-30 15:09:13
# 4  500101005    YouBike2.0_辛亥復興路口西北側   16    0   大安區  2022-09-30 15:00:26
#
#         lat        lng             ar     sareaen  \
# 0  25.02605  121.54360    復興南路二段235號前  Daan Dist.
# 1  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# 2  25.02429  121.54124    和平東路二段96巷7號  Daan Dist.
# 3  25.02351  121.54282  和平東路二段118巷33號  Daan Dist.
# 4  25.02153  121.54299     復興南路二段368號  Daan Dist.
#
#                                                snaen  \
# 0               YouBike2.0_MRT Technology Bldg. Sta.
# 1           YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2  YouBike2.0_NTUE Experiment Elementary School (...
# 3                      YouBike2.0_Heping Park (East)
# 4  YouBike2.0_Xinhai Fuxing Rd. Intersection (Nor...
#
#                                     aren  bemp  act        srcUpdateTime  \
# 0          No.235， Sec. 2， Fuxing S. Rd.    27    1  2022-09-30 15:10:23
# 1   No.273， Sec. 2， Fuxing S. Rd. (West)    21    1  2022-09-30 15:10:23
# 2    No. 7， Ln. 96， Sec. 2， Heping E. Rd     3    1  2022-09-30 15:10:23
# 3  No. 33， Ln. 118， Sec. 2， Heping E. Rd    11    1  2022-09-30 15:10:23
# 4         No. 368， Sec. 2， Fuxing S. Rd.    16    1  2022-09-30 15:10:23
#
#             updateTime             infoTime    infoDate
# 0  2022-09-30 15:10:51  2022-09-30 15:09:39  2022-09-30
# 1  2022-09-30 15:10:51  2022-09-30 15:09:13  2022-09-30
# 2  2022-09-30 15:10:51  2022-09-30 15:07:12  2022-09-30
# 3  2022-09-30 15:10:51  2022-09-30 15:09:13  2022-09-30
# 4  2022-09-30 15:10:51  2022-09-30 15:00:26  2022-09-30

# %%
data['sna'] = data['sna'].str.replace('YouBike2.0_', '')
data['snaen'] = data['snaen'].str.replace('YouBike2.0_', '')
data.head()
# Out:
# <ipython-input-4-aa5aa98c81f1>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sna'] = data['sna'].str.replace('YouBike2.0_', '')
# <ipython-input-4-aa5aa98c81f1>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['snaen'] = data['snaen'].str.replace('YouBike2.0_', '')
#          sno          sna  tot  sbi sarea                 mday       lat  \
# 0  500101001      捷運科技大樓站   28    1   大安區  2022-09-30 15:09:39  25.02605
# 1  500101002  復興南路二段273號前   22    1   大安區  2022-09-30 15:09:13  25.02565
# 2  500101003    國北教大實小東側門   16   13   大安區  2022-09-30 15:07:12  25.02429
# 3  500101004       和平公園東側   11    0   大安區  2022-09-30 15:09:13  25.02351
# 4  500101005    辛亥復興路口西北側   16    0   大安區  2022-09-30 15:00:26  25.02153
#
#          lng             ar     sareaen  \
# 0  121.54360    復興南路二段235號前  Daan Dist.
# 1  121.54357   復興南路二段273號西側  Daan Dist.
# 2  121.54124    和平東路二段96巷7號  Daan Dist.
# 3  121.54282  和平東路二段118巷33號  Daan Dist.
# 4  121.54299     復興南路二段368號  Daan Dist.
#
#                                         snaen  \
# 0                   MRT Technology Bldg. Sta.
# 1               No.273， Sec. 2， Fuxing S. Rd.
# 2    NTUE Experiment Elementary School (East)
# 3                          Heping Park (East)
# 4  Xinhai Fuxing Rd. Intersection (Northwest)
#
#                                     aren  bemp  act        srcUpdateTime  \
# 0          No.235， Sec. 2， Fuxing S. Rd.    27    1  2022-09-30 15:10:23
# 1   No.273， Sec. 2， Fuxing S. Rd. (West)    21    1  2022-09-30 15:10:23
# 2    No. 7， Ln. 96， Sec. 2， Heping E. Rd     3    1  2022-09-30 15:10:23
# 3  No. 33， Ln. 118， Sec. 2， Heping E. Rd    11    1  2022-09-30 15:10:23
# 4         No. 368， Sec. 2， Fuxing S. Rd.    16    1  2022-09-30 15:10:23
#
#             updateTime             infoTime    infoDate
# 0  2022-09-30 15:10:51  2022-09-30 15:09:39  2022-09-30
# 1  2022-09-30 15:10:51  2022-09-30 15:09:13  2022-09-30
# 2  2022-09-30 15:10:51  2022-09-30 15:07:12  2022-09-30
# 3  2022-09-30 15:10:51  2022-09-30 15:09:13  2022-09-30
# 4  2022-09-30 15:10:51  2022-09-30 15:00:26  2022-09-30

# %%
plt.scatter(data['lng'], data['lat'])
plt.show()

# %%
station_info = []
for i in data.index:
    info = 'Station(Zh): {} <br> Station(En): {} <br> Rentable: {} <br> Vacancy: {}'.format(data.sna[i], data.snaen[i], data.sbi[i], data.bemp[i])
    station_info.append(info)

for i in range(0, 3):
    print(station_info[i])
# Out:
# Station(Zh): 捷運科技大樓站 <br> Station(En): MRT Technology Bldg. Sta. <br> Rentable: 1 <br> Vacancy: 27
# Station(Zh): 復興南路二段273號前 <br> Station(En): No.273， Sec. 2， Fuxing S. Rd. <br> Rentable: 1 <br> Vacancy: 21
# Station(Zh): 國北教大實小東側門 <br> Station(En): NTUE Experiment Elementary School (East) <br> Rentable: 13 <br> Vacancy: 3

# %%
def changeColor(rentable):
    if rentable == 0:
        return 'red'
    else:
        return 'green'


bike_station_map = folium.Map(location=[data.lat.mean(), data.lng.mean()], control_scale=True, zoom_start=12)
for i in data.index:
    folium.Marker(
        location=[data.lat[i], data.lng[i]],
        popup=folium.Popup(station_info[i], max_width=500),
        icon=folium.Icon(icon='bicycle', prefix='fa', color=changeColor(data.sbi[i]))
    ).add_to(bike_station_map)
bike_station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b4e05635bdc9db080a2ee5e822e50c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b4e05635bdc9db080a2ee5e822e50c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9b4e05635bdc9db080a2ee5e822e50c4 = L.map(
#                 &quot;map_9b4e05635bdc9db080a2ee5e822e50c4&quot;,
#                 {
#                     center: [25.052711547145588, 121.54374796895178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9b4e05635bdc9db080a2ee5e822e50c4);
#
#
#
#
#
#             var tile_layer_f5a75a3ef1294d657dfc406413dd0f0a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9b4e05635bdc9db080a2ee5e822e50c4);
#
#
#             var marker_96cb5509ea8724fd27583d73d4835e0b = L.marker(
#                 [25.02605, 121.5436],
#                 {}
#             ).addTo(map_9b4e05635bdc9db080a2ee5e822e50c4);
#
#
#             var icon_d1b201205c369a4f17bb83ac47ba7468 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_96cb5509ea8724fd27583d73d4835e0b.setIcon(icon_d1b201205c369a4f17bb83ac47ba7468);
#
#
#         var popup_2589d63ed46b1e6a4b41caaedd313de2 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_e418807f7d4a632f312044a2d440d31f = $(`&lt;div id=&quot;html_e418807f7d4a632f312044a2d440d31f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station(Zh): 捷運科技大樓站 &lt;br&gt; Station(En): MRT Technology Bldg. Sta. &lt;br&gt; Rentable: 1 &lt;br&gt; Vacancy: 27&lt;/div&gt;`)[0];
#             popup_2589d63ed46b1e6a4b41caaedd313de2.setContent(html_e418807f7d4a632f312044a2d440d31f);
#
#
#         marker_96cb5509ea8724fd27583d73d4835e0b.bindPopup(popup_2589d63ed46b1e6a4b41caaedd313de2)
#         ;
#
#
#
#
#             var marker_7d9720db669907be6eae609b86a558ee = L.marker(
#                 [25.02565, 121.54357],
#                 {}
#             ).addTo(map_9b4e05635bdc9db080a2ee5e822e50c4);
#
#
#             var icon_d8748f278dce57f7ebdc57053c6718dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7d9720db669907be6eae609b86a558ee.setIcon(icon_d8748f278dce57f7ebdc57053c6718dc);
#
#
#         var popup_dc45ce47199d923c249846446209da74 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_380667e7dccf58456891163ca0650e89 = $(`&lt;div id=&quot;html_380667e7dccf58456891163ca0650e89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station(Zh): 復興南路二段273號前 &lt;br&gt; Station(En): No.273， Sec. 2， Fuxing S. Rd. &lt;br&gt; Rentable: 1 &lt;br&gt; Vacancy: 21&lt;/div&gt;`)[0];
#             popup_dc45ce47199d923c249846446209da74.setContent(html_380667e7dccf58456891163ca0650e89);
#
#
#         marker_7d9720db669907be6eae609b86a558ee.bindPopup(popup_dc45ce47199d923c249846446209da74)
#         ;
#
#
#
#
#             var marker_3f36876e2e682d12daac9564d117997c = L.marker(
#                 [25.02429, 121.54124],
#                 {}
#             ).addTo(map_9b4e05635bdc9db080a2ee5e822e50c4);
#
#
#             var icon_53923416a71e8a25eed7aabf5b7af53e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3f36876e2e682d12daac9564d117997c.setIcon(icon_53923416a71e8a25eed7aabf5b7af53e);
#
#
#         var popup_0e42d908963afbc7646ddf10e436a865 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_8846cb69eb0dd204cc92beafbddcca2f = $(`&lt;div id=&quot;html_8846cb69eb0dd204cc92beafbddcca2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station(Zh): 國北教大實小東側門 &lt;br&gt; Station(En): NTUE Experiment Elementary School (East) &lt;br&gt; Rentable: 13 &lt;br&gt; Vacancy: 3&lt;/div&gt;`)[0];
#             popup_0e42d908963afbc7646ddf10e436a865.setContent(html_8846cb69eb0dd204cc92beafbddcca2f);
#
#
#         marker_3f36876e2e682d12daac9564d117997c.bindPopup(popup_0e42d908963afbc7646ddf10e436a865)
#         ;
#
#
#
#
#             var marker_36b56cabcd26c743c8acbdb65895e2c9 = L.marker(
#                 [25.02351, 121.54282],
#                 {}
#             ).addTo(map_9b4e05635bdc9db080a2ee5e822e50c4);
#
#
#             var icon_85d1f4d370cd795e633dab27d1413ac2

# %%
bike_station_map.save('bike_station_map.html')

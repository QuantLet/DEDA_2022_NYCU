# %%
import requests
import json
import pprint
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
response = requests.get('https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json')
content  = response.content
json_tree = json.loads(content)
df = pd.DataFrame(json_tree)

# %% [markdown]
# ### 相關變數
# | Variables | Meanings |
# | :---: | :---: |
# | tot | 總樁數 |
# | sbi | 可借車輛數 |
# | bemp | 可停空位數 |
# | lat | 經度 |
# | lng | 緯度 |
# | sna | 站名 |
# | sarea | 行政區 |
# | sareaen | 英文行政區 |
# | aren | 地址 |
# | mday | 資料更新時間 |

# %%
import folium

df['lat'] = pd.to_numeric(df['lat'])
df['lng'] = pd.to_numeric(df['lng'])

loc = df[['lat','lng']].values.tolist()
mapit = folium.Map( location = loc[860], zoom_start = 12.5 )
for point in range(0, len(loc)):
    information = df['sarea'][point] + ' ' + df['sna'][point][11:] + '<br>Bikes: ' + str(df['sbi'][point]) + '<br>Docks: ' + str(df['bemp'][point]) + '<br>' + df['ar'][point] + '<br><br>Last Updated: ' + df['mday'][point]
    if df['sbi'][point] == 0:
        Color = 'lightgray'
    elif df['bemp'][point] == 0:
        Color = 'red'
    else:
        Color = 'beige'
    folium.Marker(loc[point], popup = folium.Popup(information, max_width=500), max_width='100', icon=folium.Icon(color=Color)).add_to(mapit)
mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90a072d79e13940adb6864597c111c90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90a072d79e13940adb6864597c111c90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_90a072d79e13940adb6864597c111c90 = L.map(
#                 &quot;map_90a072d79e13940adb6864597c111c90&quot;,
#                 {
#                     center: [25.04763, 121.56115],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d46f57a406a4710a9f03a20f947bce13 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90a072d79e13940adb6864597c111c90);
#
#
#             var marker_24b8d524cc8b456cf2cb8513ba81b8c9 = L.marker(
#                 [25.02605, 121.5436],
#                 {&quot;maxWidth&quot;: &quot;100&quot;}
#             ).addTo(map_90a072d79e13940adb6864597c111c90);
#
#
#             var icon_0c10566e7cf93c9b17cc0a0aac0f547b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_24b8d524cc8b456cf2cb8513ba81b8c9.setIcon(icon_0c10566e7cf93c9b17cc0a0aac0f547b);
#
#
#         var popup_e92aaf9f3b761e9394fffe43518c17e2 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_ed83e895b895f29746443f79acc60f62 = $(`&lt;div id=&quot;html_ed83e895b895f29746443f79acc60f62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大安區 捷運科技大樓站&lt;br&gt;Bikes: 19&lt;br&gt;Docks: 9&lt;br&gt;復興南路二段235號前&lt;br&gt;&lt;br&gt;Last Updated: 2022-09-29 19:00:40&lt;/div&gt;`)[0];
#             popup_e92aaf9f3b761e9394fffe43518c17e2.setContent(html_ed83e895b895f29746443f79acc60f62);
#
#
#         marker_24b8d524cc8b456cf2cb8513ba81b8c9.bindPopup(popup_e92aaf9f3b761e9394fffe43518c17e2)
#         ;
#
#
#
#
#             var marker_9bdfba26d6ff8867161fc42ffcc0c497 = L.marker(
#                 [25.02565, 121.54357],
#                 {&quot;maxWidth&quot;: &quot;100&quot;}
#             ).addTo(map_90a072d79e13940adb6864597c111c90);
#
#
#             var icon_6b62f8d94bec2db7eb1f71e49e4dcd42 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9bdfba26d6ff8867161fc42ffcc0c497.setIcon(icon_6b62f8d94bec2db7eb1f71e49e4dcd42);
#
#
#         var popup_33be232c22da733105069ade3895e0c9 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_f227c78c71d43bcd5c1cb15ed356bdd0 = $(`&lt;div id=&quot;html_f227c78c71d43bcd5c1cb15ed356bdd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大安區 復興南路二段273號前&lt;br&gt;Bikes: 20&lt;br&gt;Docks: 2&lt;br&gt;復興南路二段273號西側&lt;br&gt;&lt;br&gt;Last Updated: 2022-09-29 19:02:39&lt;/div&gt;`)[0];
#             popup_33be232c22da733105069ade3895e0c9.setContent(html_f227c78c71d43bcd5c1cb15ed356bdd0);
#
#
#         marker_9bdfba26d6ff8867161fc42ffcc0c497.bindPopup(popup_33be232c22da733105069ade3895e0c9)
#         ;
#
#
#
#
#             var marker_5e077f64fde5cbc7d853945c52cb36f1 = L.marker(
#                 [25.02429, 121.54124],
#                 {&quot;maxWidth&quot;: &quot;100&quot;}
#             ).addTo(map_90a072d79e13940adb6864597c111c90);
#
#
#             var icon_c53fd31914a5ba57a480582281249403 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e077f64fde5cbc7d853945c52cb36f1.setIcon(icon_c53fd31914a5ba57a480582281249403);
#
#
#         var popup_d5a030b12ec3530ff0496d56c931ea28 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_aa22db1247550d73a043c568a24075fb = $(`&lt;div id=&quot;html_aa22db1247550d73a043c568a24075fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大安區 國北教大實小東側門&lt;br&gt;Bikes: 4&lt;br&gt;Docks: 12&lt;br&gt;和平東路二段96巷7號&lt;br&gt;&lt;br&gt;Last Updated: 2022-09-29 19:02:13&lt;/div&gt;`)[0];
#             popup_d5a030b12ec3530ff0496d56c931ea28.setContent(html_aa22db1247550d73a043c568a24075fb);
#
#
#         marker_5e077f64fde5cbc7d853945c52cb36f1.bindPopup(popup_d5a030b12ec3530ff0496d56c931ea28)
#         ;
#
#
#
#
#             var marker_39f7ec9d450b944e358e6ea48509e1eb = L.marker(
#                 [25.02351, 121.54282],
#                 {&quot;maxWidth&quot;: &quot;100&quot;}
#             ).addTo(map_90a072d79e13940adb68

# %%
circle_map = folium.Map( location = loc[860], zoom_start = 12.5 )

for index, row in df.iterrows():
    information = row['sarea'] + ' ' + row['sna'][11:] + '<br>Bikes: ' + str(row['sbi']) + '<br>Docks: ' + str(row['bemp']) + '<br>' + row['ar'] + '<br><br>Last Updated: ' + row['mday']
    radius = 4*row['sbi']
    folium.Circle(location=[row['lat'], row['lng']], radius=radius, popup=folium.Popup(information, max_width=500), max_width='100', fill=True, fill_opacity=0.4, color='orange', weight=4.5).add_to(circle_map)
circle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70939eaca556d02226ec66fd1728b82c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70939eaca556d02226ec66fd1728b82c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_70939eaca556d02226ec66fd1728b82c = L.map(
#                 &quot;map_70939eaca556d02226ec66fd1728b82c&quot;,
#                 {
#                     center: [25.04763, 121.56115],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_748bd0fbdf12cff41ea2e55231a6e20e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70939eaca556d02226ec66fd1728b82c);
#
#
#             var circle_c2b9130b81630488cabc723e38d499b6 = L.circle(
#                 [25.02605, 121.5436],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 76, &quot;stroke&quot;: true, &quot;weight&quot;: 4.5}
#             ).addTo(map_70939eaca556d02226ec66fd1728b82c);
#
#
#         var popup_fca588602316122ad9256cc92c5cdb2d = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_ef8e9f98a0bf940e87f3eab04870165b = $(`&lt;div id=&quot;html_ef8e9f98a0bf940e87f3eab04870165b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大安區 捷運科技大樓站&lt;br&gt;Bikes: 19&lt;br&gt;Docks: 9&lt;br&gt;復興南路二段235號前&lt;br&gt;&lt;br&gt;Last Updated: 2022-09-29 18:57:13&lt;/div&gt;`)[0];
#             popup_fca588602316122ad9256cc92c5cdb2d.setContent(html_ef8e9f98a0bf940e87f3eab04870165b);
#
#
#         circle_c2b9130b81630488cabc723e38d499b6.bindPopup(popup_fca588602316122ad9256cc92c5cdb2d)
#         ;
#
#
#
#
#             var circle_72b394781dbe79b9c391faa8e0ad1a5e = L.circle(
#                 [25.02565, 121.54357],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 80, &quot;stroke&quot;: true, &quot;weight&quot;: 4.5}
#             ).addTo(map_70939eaca556d02226ec66fd1728b82c);
#
#
#         var popup_4f225c0760df9d5b2b9d076f4ac392fd = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_973b2dd4e45ed624b4d2a8c3c7c0954a = $(`&lt;div id=&quot;html_973b2dd4e45ed624b4d2a8c3c7c0954a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大安區 復興南路二段273號前&lt;br&gt;Bikes: 20&lt;br&gt;Docks: 2&lt;br&gt;復興南路二段273號西側&lt;br&gt;&lt;br&gt;Last Updated: 2022-09-29 18:57:13&lt;/div&gt;`)[0];
#             popup_4f225c0760df9d5b2b9d076f4ac392fd.setContent(html_973b2dd4e45ed624b4d2a8c3c7c0954a);
#
#
#         circle_72b394781dbe79b9c391faa8e0ad1a5e.bindPopup(popup_4f225c0760df9d5b2b9d076f4ac392fd)
#         ;
#
#
#
#
#             var circle_f155d30c2d9434432d000cc6497063a1 = L.circle(
#                 [25.02429, 121.54124],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16, &quot;stroke&quot;: true, &quot;weight&quot;: 4.5}
#             ).addTo(map_70939eaca556d02226ec66fd1728b82c);
#
#
#         var popup_2198ae5369cb317ada45d8d75d0db0d0 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var html_3a10401e9203e71551d6121738fd712b = $(`&lt;div id=&quot;html_3a10401e9203e71551d6121738fd712b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大安區 國北教大實小東側門&lt;br&gt;Bikes: 4&lt;br&gt;Docks: 12&lt;br&gt;和平東路二段96巷7號&lt;br&gt;&lt;br&gt;Last Updated: 2022-09-29 18:54:13&lt;/div&gt;`)[0];
#             popup_2198ae5369cb317ada45d8d75d0db0d0.setContent(html_3a10401e9203e71551d6121738fd712b);
#
#
#         circle_f155d30c2d9434432d000cc6497063a1.bindPopup(popup_2198ae5369cb317ada45d8d75d0db0d0)
#         ;
#
#
#
#
#             var circle_8bf6a924edb115f0019994c8392b5d11 = L.circle(
#                 [25.02351, 121.54282],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true,

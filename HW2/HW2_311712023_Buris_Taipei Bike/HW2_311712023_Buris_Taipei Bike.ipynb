# %%
import requests
import json
import pprint
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
response=requests.get('https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json')
content = response.content
json_tree = json.loads(content)

# %%
df=pd.DataFrame(json_tree)

# %%
#df=pd.read_csv('youbike-taipei.csv',sep=';')

# %%
import folium

leftRatio=df['sbi']/df['tot']*100
df['lat']=pd.to_numeric(df['lat'])
df['lng']=pd.to_numeric(df['lng'])

loc=df[['lat','lng']].values.tolist()
mapit = folium.Map( location=loc[6], zoom_start=6 )
for point in range(0, len(loc)):
    folium.Marker(loc[point], popup=[leftRatio[point],df['snaen'][point],df['sareaen'][point]]).add_to(mapit)
mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8f184162f9d0491a594532eb2f4f54e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8f184162f9d0491a594532eb2f4f54e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b8f184162f9d0491a594532eb2f4f54e = L.map(
#                 &quot;map_b8f184162f9d0491a594532eb2f4f54e&quot;,
#                 {
#                     center: [25.02253, 121.54326],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3525bb6aff64a3640830ba1699df56db = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8f184162f9d0491a594532eb2f4f54e);
#
#
#             var marker_bf9fa6ef63cbb1f30fbbbd62aeade4b8 = L.marker(
#                 [25.02605, 121.5436],
#                 {}
#             ).addTo(map_b8f184162f9d0491a594532eb2f4f54e);
#
#
#         var popup_0daf8ec4e2142ddcc2403410328dc970 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dec11786714f25c2ab3f918117416f2e = $(`&lt;div id=&quot;html_dec11786714f25c2ab3f918117416f2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[17.857142857142858, &#x27;YouBike2.0_MRT Technology Bldg. Sta.&#x27;, &#x27;Daan Dist.&#x27;]&lt;/div&gt;`)[0];
#             popup_0daf8ec4e2142ddcc2403410328dc970.setContent(html_dec11786714f25c2ab3f918117416f2e);
#
#
#         marker_bf9fa6ef63cbb1f30fbbbd62aeade4b8.bindPopup(popup_0daf8ec4e2142ddcc2403410328dc970)
#         ;
#
#
#
#
#             var marker_3f12dd48bf6c69149a659736dfd07865 = L.marker(
#                 [25.02565, 121.54357],
#                 {}
#             ).addTo(map_b8f184162f9d0491a594532eb2f4f54e);
#
#
#         var popup_3c86153ebe90ca64f9ceab930c592f50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_73c8e929bd4acfdd513c10efeb2ce55c = $(`&lt;div id=&quot;html_73c8e929bd4acfdd513c10efeb2ce55c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[18.181818181818183, &#x27;YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.&#x27;, &#x27;Daan Dist.&#x27;]&lt;/div&gt;`)[0];
#             popup_3c86153ebe90ca64f9ceab930c592f50.setContent(html_73c8e929bd4acfdd513c10efeb2ce55c);
#
#
#         marker_3f12dd48bf6c69149a659736dfd07865.bindPopup(popup_3c86153ebe90ca64f9ceab930c592f50)
#         ;
#
#
#
#
#             var marker_48edf4cf1f3a61d2092f96560ceff0af = L.marker(
#                 [25.02429, 121.54124],
#                 {}
#             ).addTo(map_b8f184162f9d0491a594532eb2f4f54e);
#
#
#         var popup_0db6c23f9899b7af947b159fbf9863fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8483ff0626ccfaffdb6d3dd45d440086 = $(`&lt;div id=&quot;html_8483ff0626ccfaffdb6d3dd45d440086&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[12.5, &#x27;YouBike2.0_NTUE Experiment Elementary School (East)&#x27;, &#x27;Daan Dist.&#x27;]&lt;/div&gt;`)[0];
#             popup_0db6c23f9899b7af947b159fbf9863fb.setContent(html_8483ff0626ccfaffdb6d3dd45d440086);
#
#
#         marker_48edf4cf1f3a61d2092f96560ceff0af.bindPopup(popup_0db6c23f9899b7af947b159fbf9863fb)
#         ;
#
#
#
#
#             var marker_3047d5d0b58b7251213daf2a35a3257b = L.marker(
#                 [25.02351, 121.54282],
#                 {}
#             ).addTo(map_b8f184162f9d0491a594532eb2f4f54e);
#
#
#         var popup_f1991b0949b379c87163bef5b93bbbe7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5a2a3992f11e612e4d9a07be3d627d32 = $(`&lt;div id=&quot;html_5a2a3992f11e612e4d9a07be3d627d32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[27.27272727272727, &#x27;YouBike2.0_Heping Park (East)&#x27;, &#x27;Daan Dist.&#x27;]&lt;/div&gt;`)[0];
#             popup_f1991b0949b379c87163bef5b93bbbe7.setContent(html_5a2a3992f11e612e4d9a07be3d627d32);
#
#
#         marker_3047d5d0b58b7251213daf2a35a3257b.bindPopup(popup_f1991b0949b379c87163bef5b93bbbe7)
#         ;
#
#
#
#
#             var marker_183d464957f472b8ee495fdabd6face2 = L.marker(
#                 [25.02153, 121.54299],
#                 {}
#             ).addTo(map_b8f184162f9d0491a594532eb2f4f54e);
#
#
#         var popup_4973bb22fdf86d26c306973ddb3a0cc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_34df9aa2c0b7c8df0b99b8751127905e = $(`&lt;div id=&quot;html_34df9aa2c0b7c8df0b99b8751127905e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[18.75, &#x27;YouBike2.0_Xinhai Fuxing Rd. Intersection (Northwest)&#x27;, &#x27;Daan Dist.&#x27;]&lt;/div&gt;`)[0];
#             popup_4973bb22fdf86d26c306973ddb3a0cc6.setContent(html_34df9aa2c0b7c8df0b99b8751127905e);
#
#
#         marker_183d464957f472b8ee495fdabd6face2.bindPopup(popup_4973bb22fdf86d26c306973ddb3a0cc6)
#         ;
#
#
#
#
#             var marker_6d78a0ae4da

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\toro_\anaconda3\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\toro_\anaconda3\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\toro_\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\toro_\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in c:\users\toro_\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\toro_\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\toro_\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
#
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\toro_\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\toro_\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\toro_\anaconda3\lib\site-packages (from requests->folium) (3.3)

# %%
print(df)
# Out:
#             sno                       sna  tot  sbi   sarea  \
# 0     500101001        YouBike2.0_捷運科技大樓站   28    5     大安區
# 1     500101002    YouBike2.0_復興南路二段273號前   22    4     大安區
# 2     500101003      YouBike2.0_國北教大實小東側門   16    2     大安區
# 3     500101004         YouBike2.0_和平公園東側   11    3     大安區
# 4     500101005      YouBike2.0_辛亥復興路口西北側   16    3     大安區
# ...         ...                       ...  ...  ...     ...
# 1170  500119087      YouBike2.0_臺大總圖書館西南側   30   20    臺大專區
# 1171  500119088        YouBike2.0_臺大黑森林西側   20    7    臺大專區
# 1172  500119089        YouBike2.0_臺大獸醫館南側   24    4    臺大專區
# 1173  500119090      YouBike2.0_臺大新體育館東南側   40   21    臺大專區
# 1174  500119091  YouBike2.0_臺大明達館北側(員工宿舍)   18    0  臺大公館校區
#
#                      mday       lat        lng             ar     sareaen  \
# 0     2022-09-28 17:07:40  25.02605  121.54360    復興南路二段235號前  Daan Dist.
# 1     2022-09-28 17:07:13  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
